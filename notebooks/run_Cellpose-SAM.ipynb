# %% [markdown]
# <a href="https://colab.research.google.com/github/JHYUIHGY/WS_lab/blob/main/notebooks/run_Cellpose-SAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-dyepv5wc
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-dyepv5wc
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit 9d59b2eec1d644fb3d4ba0f77ff19ae2900ab706
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (1.15.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (2025.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (0.21.0+cu124)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (4.11.0.86)
# Requirement already satisfied: fastremap in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (1.16.1)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (2025.3.30)
# Requirement already satisfied: roifile in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (2025.5.10)
# Requirement already satisfied: fill-voids in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (2.0.8)
# Requirement already satisfied: segment_anything in /usr/local/lib/python3.11/dist-packages (from cellpose==4.0.5.dev1+g9d59b2e) (1.0)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->cellpose==4.0.5.dev1+g9d59b2e) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->cellpose==4.0.5.dev1+g9d59b2e) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchvision->cellpose==4.0.5.dev1+g9d59b2e) (3.0.2)

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.5.dev1+g9d59b2e
# platform:       	linux
# python version: 	3.11.12
# torch version:  	2.6.0+cu124! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
#
#
# 2025-05-20 21:03:56,749 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2025-05-20 21:03:56,750 [INFO]
# cellpose version: 	4.0.5.dev1+g9d59b2e
# platform:       	linux
# python version: 	3.11.12
# torch version:  	2.6.0+cu124
# 2025-05-20 21:03:56,928 [INFO] ** TORCH CUDA version installed and working. **
# 2025-05-20 21:03:56,931 [INFO] ** TORCH CUDA version installed and working. **
# 2025-05-20 21:03:56,934 [INFO] >>>> using GPU (CUDA)
# 2025-05-20 21:04:00,408 [INFO] >>>> loading model /root/.cellpose/models/cpsam

# %% [markdown]
# Input directory with your images:

# %%
from pathlib import Path
from PIL import Image

# --- Helper function to convert PNG to .tif ---
def convert_png_to_tif_in_folder(folder_path: Path):
    """
    Converts all PNG images in a specified folder to .tif format.
    Uses pathlib.Path for path operations. .tif files are saved in the same folder.
    Skips conversion if a corresponding .tif file already exists.

    Args:
        folder_path (Path): The path object of the folder containing the PNG images.
    """
    if not folder_path.is_dir():
        print(f"Error during conversion: Folder '{folder_path}' not found or is not a directory.")
        return

    print(f"\n--- Starting PNG to .tif conversion in folder: {folder_path} ---")
    converted_count = 0
    skipped_existing_tif_count = 0
    error_count = 0
    png_files_found = 0

    for item in folder_path.iterdir():
        if item.is_file() and item.suffix.lower() == ".png":
            png_files_found += 1
            png_path = item
            # Output file will have .tif extension
            tif_path = png_path.with_suffix(".tif")

            if tif_path.exists():
                # print(f".tif version '{tif_path.name}' already exists for '{png_path.name}'. Skipping conversion.")
                skipped_existing_tif_count += 1
                continue

            try:
                img = Image.open(png_path)

                save_all_frames = False
                if hasattr(img, 'n_frames') and img.n_frames > 1:
                    save_all_frames = True

                # Pillow's format name is "TIFF", even for .tif extension
                img.save(tif_path, format="TIFF", save_all=save_all_frames, compression="tiff_lzw")
                print(f"Converted '{png_path.name}' to '{tif_path.name}'")
                converted_count += 1
            except Exception as e:
                print(f"Could not convert '{png_path.name}'. Error: {e}")
                error_count += 1

    print(f"--- PNG to .tif conversion finished ---")
    if png_files_found == 0:
        print("No PNG files found in the directory for conversion.")
    else:
        if converted_count > 0:
            print(f"Successfully converted {converted_count} PNG image(s) to .tif.")
        if skipped_existing_tif_count > 0:
            print(f"{skipped_existing_tif_count} PNG image(s) already had corresponding .tif versions and were skipped.")
        if error_count > 0:
            print(f"Encountered errors for {error_count} PNG image(s) during conversion.")
        if converted_count == 0 and skipped_existing_tif_count == png_files_found and error_count == 0 :
             print("All PNG files already have corresponding .tif versions or no new PNGs to convert.")
    print("----------------------------------------\n")

# --- Helper function to delete all non-.tif files ---
def delete_non_tif_files(folder_path: Path):
    """
    Deletes all files in the specified folder except for .tif files.
    WARNING: This operation is destructive and irreversible.

    Args:
        folder_path (Path): The path object of the folder to clean up.
    """
    if not folder_path.is_dir():
        print(f"Error during deletion: Folder '{folder_path}' not found or is not a directory.")
        return

    print(f"\n--- Starting deletion of non-.tif files in folder: {folder_path} ---")
    print("WARNING: This will delete all files except those with the .tif extension.")
    deleted_count = 0
    kept_count = 0
    error_delete_count = 0

    for item in folder_path.iterdir():
        if item.is_file():  # Only process files
            if item.suffix.lower() != ".tif":
                try:
                    item.unlink()  # Delete the file
                    print(f"Deleted: {item.name}")
                    deleted_count += 1
                except Exception as e:
                    print(f"Error deleting {item.name}: {e}")
                    error_delete_count +=1
            else:
                kept_count += 1
        # This function does not delete subdirectories, only files.

    print(f"--- File deletion finished ---")
    if deleted_count > 0:
        print(f"Successfully deleted {deleted_count} non-.tif file(s).")
    else:
        print("No non-.tif files found to delete (or only .tif files were present).")
    if error_delete_count > 0:
        print(f"Failed to delete {error_delete_count} file(s).")
    print(f"Kept {kept_count} .tif file(s).")
    print("----------------------------\n")

# --- original script logic starts below ---

# *** change to your google drive folder path ***
directory_path_str = "/content/drive/MyDrive/BMRB_images" # Example path
directory_path = Path(directory_path_str)

if not directory_path.exists():
  raise FileNotFoundError(f"Directory '{directory_path}' does not exist. Please check the path.")
if not directory_path.is_dir():
  raise NotADirectoryError(f"Path '{directory_path}' is not a directory. Please check the path.")

# 1. Convert PNG files to .tif files
convert_png_to_tif_in_folder(directory_path)

# 2. Delete all other files except .tif files from the directory
#    (This includes original PNGs if conversion was successful, and any other file types)
delete_non_tif_files(directory_path)

# *** image extension to look for (should be .tif) ***
image_ext = ".tif"

# 3. List all remaining .tif files, excluding masks and flows
files = natsorted([
    f for f in directory_path.glob("*" + image_ext)
    if "_masks" not in f.name and "_flows" not in f.name
])

if not files:
  print(f"No image files with extension '{image_ext}' (excluding '_masks' and '_flows') found in '{directory_path}'.")
  print("This could be due to various reasons: no initial .tif files, no PNGs to convert, all files filtered out, or issues during conversion/deletion.")
else:
  print(f"{len(files)} images with extension '{image_ext}' (excluding '_masks' and '_flows') found in folder '{directory_path}':")

for f_path in files:
  print(f_path.name)
# Out:
# --- Starting PNG to .tif conversion in folder: /content/drive/MyDrive/BMRB_images ---
# Converted 'fig1_s12104-016-9668-9.png' to 'fig1_s12104-016-9668-9.tif'
# Converted 'fig1_s12104-013-9478-2.png' to 'fig1_s12104-013-9478-2.tif'
# Converted 'fig1_s12104-012-9383-0.png' to 'fig1_s12104-012-9383-0.tif'
# Converted 'fig1_s12104-007-9072-6.png' to 'fig1_s12104-007-9072-6.tif'
# Converted 'fig1_s12104-017-9726-y.png' to 'fig1_s12104-017-9726-y.tif'
# Converted 'fig1_s12104-012-9423-9.png' to 'fig1_s12104-012-9423-9.tif'
# Converted 'fig1_s12104-010-9238-5.png' to 'fig1_s12104-010-9238-5.tif'
# Converted 'fig1_s12104-008-9136-2.png' to 'fig1_s12104-008-9136-2.tif'
# Converted 'fig1_s12104-015-9642-y.png' to 'fig1_s12104-015-9642-y.tif'
# Converted 'fig1_s12104-011-9345-y.png' to 'fig1_s12104-011-9345-y.tif'
# Converted 'fig1_s12104-014-9573-z.png' to 'fig1_s12104-014-9573-z.tif'
# Converted 'fig1_s12104-018-9824-5.png' to 'fig1_s12104-018-9824-5.tif'
# Converted 'fig1_s12104-015-9598-y.png' to 'fig1_s12104-015-9598-y.tif'
# Converted 'fig1_s12104-013-9483-5.png' to 'fig1_s12104-013-9483-5.tif'
# Converted 'fig1_s12104-013-9481-7.png' to 'fig1_s12104-013-9481-7.tif'
# Converted 'fig1_s12104-012-9436-4.png' to 'fig1_s12104-012-9436-4.tif'
# Converted 'fig1_s12104-012-9365-2.png' to 'fig1_s12104-012-9365-2.tif'
# Converted 'fig1_s12104-009-9167-3.png' to 'fig1_s12104-009-9167-3.tif'
# Converted 'fig1_s12104-014-9562-2.png' to 'fig1_s12104-014-9562-2.tif'
# Converted 'fig1_s12104-010-9209-x.png' to 'fig1_s12104-010-9209-x.tif'
# Converted 'fig1_s12104-013-9472-8.png' to 'fig1_s12104-013-9472-8.tif'
# Converted 'fig1_s12104-013-9467-5.png' to 'fig1_s12104-013-9467-5.tif'
# Converted 'fig1_s12104-014-9542-6.png' to 'fig1_s12104-014-9542-6.tif'
# Converted 'fig1_s12104-008-9116-6.png' to 'fig1_s12104-008-9116-6.tif'
# Converted 'fig1_s12104-013-9465-7.png' to 'fig1_s12104-013-9465-7.tif'
# Converted 'fig1_s12104-012-9409-7.png' to 'fig1_s12104-012-9409-7.tif'
# Converted 'fig1_s12104-013-9487-1.png' to 'fig1_s12104-013-9487-1.tif'
# Converted 'fig1_s12104-011-9335-0.png' to 'fig1_s12104-011-9335-0.tif'
# Converted 'fig1_s12104-008-9082-z.png' to 'fig1_s12104-008-9082-z.tif'
# Converted 'fig1_s12104-011-9300-y.png' to 'fig1_s12104-011-9300-y.tif'
# Converted 'fig1_s12104-012-9381-2.png' to 'fig1_s12104-012-9381-2.tif'
# Converted 'fig1_s12104-009-9147-7.png' to 'fig1_s12104-009-9147-7.tif'
# Converted 'fig1_s12104-011-9331-4.png' to 'fig1_s12104-011-9331-4.tif'
# Converted 'fig1_s12104-012-9429-3.png' to 'fig1_s12104-012-9429-3.tif'
# Converted 'fig1_s12104-014-9568-9.png' to 'fig1_s12104-014-9568-9.tif'
# Converted 'fig1_s12104-012-9367-0.png' to 'fig1_s12104-012-9367-0.tif'
# Converted 'fig1_s12104-017-9787-y.png' to 'fig1_s12104-017-9787-y.tif'
# Converted 'fig1_s12104-010-9246-5.png' to 'fig1_s12104-010-9246-5.tif'
# Converted 'fig1_s12104-020-09927-w.png' to 'fig1_s12104-020-09927-w.tif'
# Converted 'fig1_s12104-019-09907-9.png' to 'fig1_s12104-019-09907-9.tif'
# Converted 'fig1_s12104-016-9698-3.png' to 'fig1_s12104-016-9698-3.tif'
# Converted 'fig1_s12104-012-9410-1.png' to 'fig1_s12104-012-9410-1.tif'
# Converted 'fig1_s12104-016-9710-y.png' to 'fig1_s12104-016-9710-y.tif'
# Converted 'fig1_s12104-017-9791-2.png' to 'fig1_s12104-017-9791-2.tif'
# Converted 'fig1_s12104-018-9819-2.png' to 'fig1_s12104-018-9819-2.tif'
# Converted 'fig1_s12104-016-9691-x.png' to 'fig1_s12104-016-9691-x.tif'
# Converted 'fig1_s12104-010-9262-5.png' to 'fig1_s12104-010-9262-5.tif'
# Converted 'fig1_s12104-010-9216-y.png' to 'fig1_s12104-010-9216-y.tif'
# Converted 'fig1_s12104-010-9260-7.png' to 'fig1_s12104-010-9260-7.tif'
# Converted 'fig1_s12104-014-9577-8.png' to 'fig1_s12104-014-9577-8.tif'
# Converted 'fig1_s12104-010-9266-1.png' to 'fig1_s12104-010-9266-1.tif'
# Converted 'fig1_s12104-016-9707-6.png' to 'fig1_s12104-016-9707-6.tif'
# Converted 'fig1_s12104-017-9732-0.png' to 'fig1_s12104-017-9732-0.tif'
# Converted 'fig1_s12104-007-9011-6.png' to 'fig1_s12104-007-9011-6.tif'
# Converted 'fig1_s12104-008-9088-6.png' to 'fig1_s12104-008-9088-6.tif'
# Converted 'fig1_s12104-008-9095-7.png' to 'fig1_s12104-008-9095-7.tif'
# Converted 'fig1_s12104-017-9769-0.png' to 'fig1_s12104-017-9769-0.tif'
# Converted 'fig1_s12104-012-9452-4.png' to 'fig1_s12104-012-9452-4.tif'
# Converted 'fig1_s12104-012-9394-x.png' to 'fig1_s12104-012-9394-x.tif'
# Converted 'fig1_s12104-016-9686-7.png' to 'fig1_s12104-016-9686-7.tif'
# Converted 'fig1_s12104-018-9856-x.png' to 'fig1_s12104-018-9856-x.tif'
# Converted 'fig1_s12104-017-9731-1.png' to 'fig1_s12104-017-9731-1.tif'
# Converted 'fig1_s12104-019-09890-1.png' to 'fig1_s12104-019-09890-1.tif'
# Converted 'fig1_s12104-007-9013-4.png' to 'fig1_s12104-007-9013-4.tif'
# Converted 'fig1_s12104-011-9302-9.png' to 'fig1_s12104-011-9302-9.tif'
# Converted 'fig1_s12104-013-9506-2.png' to 'fig1_s12104-013-9506-2.tif'
# Converted 'fig1_s12104-007-9015-2.png' to 'fig1_s12104-007-9015-2.tif'
# Converted 'fig1_s12104-008-9097-5.png' to 'fig1_s12104-008-9097-5.tif'
# Converted 'fig1_s12104-017-9773-4.png' to 'fig1_s12104-017-9773-4.tif'
# Converted 'fig1_s12104-012-9360-7.png' to 'fig1_s12104-012-9360-7.tif'
# Converted 'fig1_s12104-012-9448-0.png' to 'fig1_s12104-012-9448-0.tif'
# Converted 'fig1_s12104-007-9017-0.png' to 'fig1_s12104-007-9017-0.tif'
# Converted 'fig1_s12104-011-9347-9.png' to 'fig1_s12104-011-9347-9.tif'
# Converted 'fig1_s12104-020-09994-z.png' to 'fig1_s12104-020-09994-z.tif'
# Converted 'fig1_s12104-013-9507-1.png' to 'fig1_s12104-013-9507-1.tif'
# Converted 'fig1_s12104-012-9392-z.png' to 'fig1_s12104-012-9392-z.tif'
# Converted 'fig1_s12104-017-9776-1.png' to 'fig1_s12104-017-9776-1.tif'
# Converted 'fig1_s12104-018-09870-x.png' to 'fig1_s12104-018-09870-x.tif'
# Converted 'fig1_s12104-015-9654-7.png' to 'fig1_s12104-015-9654-7.tif'
# Converted 'fig1_s12104-015-9610-6.png' to 'fig1_s12104-015-9610-6.tif'
# Converted 'fig1_s12104-015-9657-4.png' to 'fig1_s12104-015-9657-4.tif'
# Converted 'fig1_s12104-007-9033-0.png' to 'fig1_s12104-007-9033-0.tif'
# Converted 'fig1_s12104-016-9673-z.png' to 'fig1_s12104-016-9673-z.tif'
# Converted 'fig1_s12104-017-9749-4.png' to 'fig1_s12104-017-9749-4.tif'
# Converted 'fig1_s12104-015-9612-4.png' to 'fig1_s12104-015-9612-4.tif'
# Converted 'fig1_s12104-023-10159-x.png' to 'fig1_s12104-023-10159-x.tif'
# Converted 'fig1_s12104-012-9405-y.png' to 'fig1_s12104-012-9405-y.tif'
# Converted 'fig1_s12104-017-9761-8.png' to 'fig1_s12104-017-9761-8.tif'
# Converted 'fig1_s12104-020-09963-6.png' to 'fig1_s12104-020-09963-6.tif'
# Converted 'fig1_s12104-017-9770-7.png' to 'fig1_s12104-017-9770-7.tif'
# Converted 'fig1_s12104-015-9660-9.png' to 'fig1_s12104-015-9660-9.tif'
# Converted 'fig1_s12104-008-9086-8.png' to 'fig1_s12104-008-9086-8.tif'
# Converted 'fig1_s12104-015-9616-0.png' to 'fig1_s12104-015-9616-0.tif'
# Converted 'fig1_s12104-012-9376-z.png' to 'fig1_s12104-012-9376-z.tif'
# Converted 'fig1_s12104-013-9528-9.png' to 'fig1_s12104-013-9528-9.tif'
# Converted 'fig1_s12104-015-9614-2.png' to 'fig1_s12104-015-9614-2.tif'
# Converted 'fig1_s12104-016-9725-4.png' to 'fig1_s12104-016-9725-4.tif'
# Converted 'fig1_s12104-019-09917-7.png' to 'fig1_s12104-019-09917-7.tif'
# Converted 'fig1_s12104-008-9105-9.png' to 'fig1_s12104-008-9105-9.tif'
# Converted 'fig1_s12104-009-9152-x.png' to 'fig1_s12104-009-9152-x.tif'
# Converted 'fig1_s12104-009-9201-5.png' to 'fig1_s12104-009-9201-5.tif'
# Converted 'fig1_s12104-019-09904-y.png' to 'fig1_s12104-019-09904-y.tif'
# Converted 'fig1_s12104-020-09943-w.png' to 'fig1_s12104-020-09943-w.tif'
# Converted 'fig1_s12104-011-9294-5.png' to 'fig1_s12104-011-9294-5.tif'
# Converted 'fig1_s12104-019-09874-1.png' to 'fig1_s12104-019-09874-1.tif'
# Converted 'fig1_s12104-020-09933-y.png' to 'fig1_s12104-020-09933-y.tif'
# Converted 'fig1_s12104-018-9849-9.png' to 'fig1_s12104-018-9849-9.tif'
# Converted 'fig1_s12104-010-9268-z.png' to 'fig1_s12104-010-9268-z.tif'
# Converted 'fig1_s12104-015-9644-9.png' to 'fig1_s12104-015-9644-9.tif'
# Converted 'fig1_s12104-018-9806-7.png' to 'fig1_s12104-018-9806-7.tif'
# Converted 'fig1_s12104-007-9019-y.png' to 'fig1_s12104-007-9019-y.tif'
# Converted 'fig1_s12104-009-9203-3.png' to 'fig1_s12104-009-9203-3.tif'
# Converted 'fig1_s12104-009-9154-8.png' to 'fig1_s12104-009-9154-8.tif'
# Converted 'fig1_s12104-013-9489-z.png' to 'fig1_s12104-013-9489-z.tif'
# Converted 'fig1_s12104-010-9259-0.png' to 'fig1_s12104-010-9259-0.tif'
# Converted 'fig1_s12104-013-9510-6.png' to 'fig1_s12104-013-9510-6.tif'
# Converted 'fig1_s12104-007-9074-4.png' to 'fig1_s12104-007-9074-4.tif'
# Converted 'fig1_s12104-014-9554-2.png' to 'fig1_s12104-014-9554-2.tif'
# Converted 'fig1_s12104-008-9087-7.png' to 'fig1_s12104-008-9087-7.tif'
# Converted 'fig1_s12104-015-9648-5.png' to 'fig1_s12104-015-9648-5.tif'
# Converted 'fig1_s12104-008-9141-5.png' to 'fig1_s12104-008-9141-5.tif'
# Converted 'fig1_s12104-009-9170-8.png' to 'fig1_s12104-009-9170-8.tif'
# Converted 'fig1_s12104-009-9181-5.png' to 'fig1_s12104-009-9181-5.tif'
# Converted 'fig1_s12104-009-9158-4.png' to 'fig1_s12104-009-9158-4.tif'
# Converted 'fig1_s12104-014-9544-4.png' to 'fig1_s12104-014-9544-4.tif'
# Converted 'fig1_s12104-016-9712-9.png' to 'fig1_s12104-016-9712-9.tif'
# Converted 'fig1_s12104-008-9134-4.png' to 'fig1_s12104-008-9134-4.tif'
# Converted 'fig1_s12104-007-9045-9.png' to 'fig1_s12104-007-9045-9.tif'
# Converted 'fig1_s12104-020-09947-6.png' to 'fig1_s12104-020-09947-6.tif'
# Converted 'fig1_s12104-020-09986-z.png' to 'fig1_s12104-020-09986-z.tif'
# Converted 'fig1_s12104-018-9822-7.png' to 'fig1_s12104-018-9822-7.tif'
# Converted 'fig1_s12104-015-9596-0.png' to 'fig1_s12104-015-9596-0.tif'
# Converted 'fig1_s12104-016-9706-7.png' to 'fig1_s12104-016-9706-7.tif'
# Converted 'fig1_s12104-019-09901-1.png' to 'fig1_s12104-019-09901-1.tif'
# Converted 'fig1_s12104-011-9317-2.png' to 'fig1_s12104-011-9317-2.tif'
# Converted 'fig1_s12104-010-9288-8.png' to 'fig1_s12104-010-9288-8.tif'
# Converted 'fig1_s12104-018-9812-9.png' to 'fig1_s12104-018-9812-9.tif'
# Converted 'fig1_s12104-013-9537-8.png' to 'fig1_s12104-013-9537-8.tif'
# Converted 'fig1_s12104-017-9743-x.png' to 'fig1_s12104-017-9743-x.tif'
# Converted 'fig1_s12104-009-9185-1.png' to 'fig1_s12104-009-9185-1.tif'
# Converted 'fig1_s12104-016-9675-x.png' to 'fig1_s12104-016-9675-x.tif'
# Converted 'fig1_s12104-012-9396-8.png' to 'fig1_s12104-012-9396-8.tif'
# Converted 'fig1_s12104-018-9800-0.png' to 'fig1_s12104-018-9800-0.tif'
# Converted 'fig1_s12104-011-9296-3.png' to 'fig1_s12104-011-9296-3.tif'
# Converted 'fig1_s12104-014-9593-8.png' to 'fig1_s12104-014-9593-8.tif'
# Converted 'fig1_s12104-015-9627-x.png' to 'fig1_s12104-015-9627-x.tif'
# Converted 'fig1_s12104-016-9723-6.png' to 'fig1_s12104-016-9723-6.tif'
# Converted 'fig1_s12104-020-09982-3.png' to 'fig1_s12104-020-09982-3.tif'
# Converted 'fig1_s12104-015-9626-y.png' to 'fig1_s12104-015-9626-y.tif'
# Converted 'fig1_s12104-010-9277-y.png' to 'fig1_s12104-010-9277-y.tif'
# Converted 'fig1_s12104-010-9282-1.png' to 'fig1_s12104-010-9282-1.tif'
# Converted 'fig1_s12104-010-9244-7.png' to 'fig1_s12104-010-9244-7.tif'
# Converted 'fig1_s12104-010-9232-y.png' to 'fig1_s12104-010-9232-y.tif'
# Converted 'fig1_s12104-010-9280-3.png' to 'fig1_s12104-010-9280-3.tif'
# Converted 'fig1_s12104-019-09885-y.png' to 'fig1_s12104-019-09885-y.tif'
# Converted 'fig1_s12104-016-9669-8.png' to 'fig1_s12104-016-9669-8.tif'
# Converted 'fig1_s12104-017-9786-z.png' to 'fig1_s12104-017-9786-z.tif'
# Converted 'fig1_s12104-009-9153-9.png' to 'fig1_s12104-009-9153-9.tif'
# Converted 'fig1_s12104-007-9055-7.png' to 'fig1_s12104-007-9055-7.tif'
# Converted 'fig1_s12104-015-9643-x.png' to 'fig1_s12104-015-9643-x.tif'
# Converted 'fig1_s12104-017-9762-7.png' to 'fig1_s12104-017-9762-7.tif'
# Converted 'fig1_s12104-019-09903-z.png' to 'fig1_s12104-019-09903-z.tif'
# Converted 'fig1_s12104-014-9561-3.png' to 'fig1_s12104-014-9561-3.tif'
# Converted 'fig1_s12104-014-9594-7.png' to 'fig1_s12104-014-9594-7.tif'
# Converted 'fig1_s12104-020-09950-x.png' to 'fig1_s12104-020-09950-x.tif'
# Converted 'fig1_s12104-013-9486-2.png' to 'fig1_s12104-013-9486-2.tif'
# Converted 'fig1_s12104-017-9782-3.png' to 'fig1_s12104-017-9782-3.tif'
# Converted 'fig1_s12104-007-9061-9.png' to 'fig1_s12104-007-9061-9.tif'
# Converted 'fig1_s12104-011-9333-2.png' to 'fig1_s12104-011-9333-2.tif'
# Converted 'fig1_s12104-015-9639-6.png' to 'fig1_s12104-015-9639-6.tif'
# Converted 'fig1_s12104-011-9303-8.png' to 'fig1_s12104-011-9303-8.tif'
# Converted 'fig1_s12104-010-9251-8.png' to 'fig1_s12104-010-9251-8.tif'
# Converted 'fig1_s12104-007-9012-5.png' to 'fig1_s12104-007-9012-5.tif'
# Converted 'fig1_s12104-013-9471-9.png' to 'fig1_s12104-013-9471-9.tif'
# Converted 'fig1_s12104-013-9459-5.png' to 'fig1_s12104-013-9459-5.tif'
# Converted 'fig1_s12104-020-09973-4.png' to 'fig1_s12104-020-09973-4.tif'
# Converted 'fig1_s12104-008-9117-5.png' to 'fig1_s12104-008-9117-5.tif'
# Converted 'fig1_s12104-012-9398-6.png' to 'fig1_s12104-012-9398-6.tif'
# Converted 'fig1_s12104-009-9165-5.png' to 'fig1_s12104-009-9165-5.tif'
# Converted 'fig1_s12104-018-9811-x.png' to 'fig1_s12104-018-9811-x.tif'
# Converted 'fig1_s12104-011-9339-9.png' to 'fig1_s12104-011-9339-9.tif'
# Converted 'fig1_s12104-020-09999-8.png' to 'fig1_s12104-020-09999-8.tif'
# Converted 'fig1_s12104-007-9026-z.png' to 'fig1_s12104-007-9026-z.tif'
# Converted 'fig1_s12104-015-9618-y.png' to 'fig1_s12104-015-9618-y.tif'
# Converted 'fig1_s12104-016-9667-x.png' to 'fig1_s12104-016-9667-x.tif'
# Converted 'fig1_s12104-014-9591-x.png' to 'fig1_s12104-014-9591-x.tif'
# Converted 'fig1_s12104-014-9560-4.png' to 'fig1_s12104-014-9560-4.tif'
# Converted 'fig1_s12104-008-9084-x.png' to 'fig1_s12104-008-9084-x.tif'
# Converted 'fig1_s12104-013-9539-6.png' to 'fig1_s12104-013-9539-6.tif'
# Converted 'fig1_s12104-016-9694-7.png' to 'fig1_s12104-016-9694-7.tif'
# Converted 'fig1_s12104-014-9580-0.png' to 'fig1_s12104-014-9580-0.tif'
# Converted 'fig1_s12104-018-9809-4.png' to 'fig1_s12104-018-9809-4.tif'
# Converted 'fig1_s12104-016-9693-8.png' to 'fig1_s12104-016-9693-8.tif'
# Converted 'fig1_s12104-017-9772-5.png' to 'fig1_s12104-017-9772-5.tif'
# Converted 'fig1_s12104-014-9558-y.png' to 'fig1_s12104-014-9558-y.tif'
# Converted 'fig1_s12104-017-9758-3.png' to 'fig1_s12104-017-9758-3.tif'
# Converted 'fig1_s12104-017-9748-5.png' to 'fig1_s12104-017-9748-5.tif'
# Converted 'fig1_s12104-013-9466-6.png' to 'fig1_s12104-013-9466-6.tif'
# Converted 'fig1_s12104-015-9656-5.png' to 'fig1_s12104-015-9656-5.tif'
# Converted 'fig1_s12104-011-9301-x.png' to 'fig1_s12104-011-9301-x.tif'
# Converted 'fig1_s12104-013-9497-z.png' to 'fig1_s12104-013-9497-z.tif'
# Converted 'fig1_s12104-009-9202-4.png' to 'fig1_s12104-009-9202-4.tif'
# Converted 'fig1_s12104-017-9760-9.png' to 'fig1_s12104-017-9760-9.tif'
# Converted 'fig1_s12104-018-9799-2.png' to 'fig1_s12104-018-9799-2.tif'
# Converted 'fig1_s12104-016-9724-5.png' to 'fig1_s12104-016-9724-5.tif'
# Converted 'fig1_s12104-007-9030-3.png' to 'fig1_s12104-007-9030-3.tif'
# Converted 'fig1_s12104-019-09910-0.png' to 'fig1_s12104-019-09910-0.tif'
# Converted 'fig1_s12104-008-9137-1.png' to 'fig1_s12104-008-9137-1.tif'
# Converted 'fig1_s12104-012-9359-0.png' to 'fig1_s12104-012-9359-0.tif'
# Converted 'fig1_s12104-014-9543-5.png' to 'fig1_s12104-014-9543-5.tif'
# Converted 'fig1_s12104-008-9131-7.png' to 'fig1_s12104-008-9131-7.tif'
# Converted 'fig1_s12104-011-9346-x.png' to 'fig1_s12104-011-9346-x.tif'
# Converted 'fig1_s12104-019-09871-4.png' to 'fig1_s12104-019-09871-4.tif'
# Converted 'fig1_s12104-017-9765-4.png' to 'fig1_s12104-017-9765-4.tif'
# Converted 'fig1_s12104-015-9621-3.png' to 'fig1_s12104-015-9621-3.tif'
# Converted 'fig1_s12104-013-9479-1.png' to 'fig1_s12104-013-9479-1.tif'
# Converted 'fig1_s12104-014-9547-1.png' to 'fig1_s12104-014-9547-1.tif'
# Converted 'fig1_s12104-007-9075-3.png' to 'fig1_s12104-007-9075-3.tif'
# Converted 'fig1_s12104-017-9767-2.png' to 'fig1_s12104-017-9767-2.tif'
# Converted 'fig1_s12104-019-09900-2.png' to 'fig1_s12104-019-09900-2.tif'
# Converted 'fig1_s12104-009-9206-0.png' to 'fig1_s12104-009-9206-0.tif'
# Converted 'fig1_s12104-020-09978-z.png' to 'fig1_s12104-020-09978-z.tif'
# Converted 'fig1_s12104-008-9079-7.png' to 'fig1_s12104-008-9079-7.tif'
# Converted 'fig1_s12104-007-9071-7.png' to 'fig1_s12104-007-9071-7.tif'
# Converted 'fig1_s12104-008-9133-5.png' to 'fig1_s12104-008-9133-5.tif'
# Converted 'fig1_s12104-011-9309-2.png' to 'fig1_s12104-011-9309-2.tif'
# Converted 'fig1_s12104-014-9541-7.png' to 'fig1_s12104-014-9541-7.tif'
# Converted 'fig1_s12104-009-9204-2.png' to 'fig1_s12104-009-9204-2.tif'
# Converted 'fig1_s12104-007-9057-5.png' to 'fig1_s12104-007-9057-5.tif'
# Converted 'fig1_s12104-013-9529-8.png' to 'fig1_s12104-013-9529-8.tif'
# Converted 'fig1_s12104-007-9073-5.png' to 'fig1_s12104-007-9073-5.tif'
# Converted 'fig1_s12104-008-9107-7.png' to 'fig1_s12104-008-9107-7.tif'
# Converted 'fig1_s12104-012-9388-8.png' to 'fig1_s12104-012-9388-8.tif'
# Converted 'fig1_s12104-015-9641-z.png' to 'fig1_s12104-015-9641-z.tif'
# Converted 'fig1_s12104-018-9814-7.png' to 'fig1_s12104-018-9814-7.tif'
# Converted 'fig1_s12104-017-9779-y.png' to 'fig1_s12104-017-9779-y.tif'
# Converted 'fig1_s12104-015-9600-8.png' to 'fig1_s12104-015-9600-8.tif'
# Converted 'fig1_s12104-012-9454-2.png' to 'fig1_s12104-012-9454-2.tif'
# Converted 'fig1_s12104-019-09914-w.png' to 'fig1_s12104-019-09914-w.tif'
# Converted 'fig1_s12104-012-9422-x.png' to 'fig1_s12104-012-9422-x.tif'
# Converted 'fig1_s12104-012-9420-z.png' to 'fig1_s12104-012-9420-z.tif'
# Converted 'fig1_s12104-020-09929-8.png' to 'fig1_s12104-020-09929-8.tif'
# Converted 'fig1_s12104-012-9450-6.png' to 'fig1_s12104-012-9450-6.tif'
# Converted 'fig1_s12104-011-9334-1.png' to 'fig1_s12104-011-9334-1.tif'
# Converted 'fig1_s12104-010-9235-8.png' to 'fig1_s12104-010-9235-8.tif'
# Converted 'fig1_s12104-012-9393-y.png' to 'fig1_s12104-012-9393-y.tif'
# Converted 'fig1_s12104-008-9102-z.png' to 'fig1_s12104-008-9102-z.tif'
# Converted 'fig1_s12104-013-9505-3.png' to 'fig1_s12104-013-9505-3.tif'
# Converted 'fig1_s12104-018-9807-6.png' to 'fig1_s12104-018-9807-6.tif'
# Converted 'fig1_s12104-010-9269-y.png' to 'fig1_s12104-010-9269-y.tif'
# Converted 'fig1_s12104-015-9615-1.png' to 'fig1_s12104-015-9615-1.tif'
# Converted 'fig1_s12104-019-09895-w.png' to 'fig1_s12104-019-09895-w.tif'
# Converted 'fig1_s12104-018-9848-x.png' to 'fig1_s12104-018-9848-x.tif'
# Converted 'fig1_s12104-012-9362-5.png' to 'fig1_s12104-012-9362-5.tif'
# Converted 'fig1_s12104-009-9188-y.png' to 'fig1_s12104-009-9188-y.tif'
# Converted 'fig1_s12104-015-9599-x.png' to 'fig1_s12104-015-9599-x.tif'
# Converted 'fig1_s12104-007-9038-8.png' to 'fig1_s12104-007-9038-8.tif'
# Converted 'fig1_s12104-010-9207-z.png' to 'fig1_s12104-010-9207-z.tif'
# Converted 'fig1_s12104-020-09984-1.png' to 'fig1_s12104-020-09984-1.tif'
# Converted 'fig1_s12104-013-9523-1.png' to 'fig1_s12104-013-9523-1.tif'
# Converted 'fig1_s12104-014-9548-0.png' to 'fig1_s12104-014-9548-0.tif'
# Converted 'fig1_s12104-012-9404-z.png' to 'fig1_s12104-012-9404-z.tif'
# Converted 'fig1_s12104-020-09980-5.png' to 'fig1_s12104-020-09980-5.tif'
# Converted 'fig1_s12104-014-9540-8.png' to 'fig1_s12104-014-9540-8.tif'
# Converted 'fig1_s12104-012-9382-1.png' to 'fig1_s12104-012-9382-1.tif'
# Converted 'fig1_s12104-012-9406-x.png' to 'fig1_s12104-012-9406-x.tif'
# Converted 'fig2_s12104-018-9837-0.png' to 'fig2_s12104-018-9837-0.tif'
# Converted 'fig1_s12104-015-9611-5.png' to 'fig1_s12104-015-9611-5.tif'
# Converted 'fig1_s12104-012-9380-3.png' to 'fig1_s12104-012-9380-3.tif'
# Converted 'fig1_s12104-018-9825-4.png' to 'fig1_s12104-018-9825-4.tif'
# Converted 'fig1_s12104-009-9151-y.png' to 'fig1_s12104-009-9151-y.tif'
# Converted 'fig1_s12104-013-9484-4.png' to 'fig1_s12104-013-9484-4.tif'
# Converted 'fig1_s12104-008-9108-6.png' to 'fig1_s12104-008-9108-6.tif'
# Converted 'fig1_s12104-019-09905-x.png' to 'fig1_s12104-019-09905-x.tif'
# Converted 'fig1_s12104-010-9220-2.png' to 'fig1_s12104-010-9220-2.tif'
# Converted 'fig1_s12104-016-9687-6.png' to 'fig1_s12104-016-9687-6.tif'
# Converted 'fig1_s12104-009-9195-z.png' to 'fig1_s12104-009-9195-z.tif'
# Converted 'fig1_s12104-007-9048-6.png' to 'fig1_s12104-007-9048-6.tif'
# Converted 'fig1_s12104-012-9428-4.png' to 'fig1_s12104-012-9428-4.tif'
# Converted 'fig1_s12104-019-09921-x.png' to 'fig1_s12104-019-09921-x.tif'
# Converted 'fig1_s12104-010-9267-0.png' to 'fig1_s12104-010-9267-0.tif'
# Converted 'fig1_s12104-018-9859-7.png' to 'fig1_s12104-018-9859-7.tif'
# Converted 'fig1_s12104-007-9068-2.png' to 'fig1_s12104-007-9068-2.tif'
# Converted 'fig1_s12104-009-9182-4.png' to 'fig1_s12104-009-9182-4.tif'
# Converted 'fig1_s12104-008-9128-2.png' to 'fig1_s12104-008-9128-2.tif'
# Converted 'fig1_s12104-009-9184-2.png' to 'fig1_s12104-009-9184-2.tif'
# Converted 'fig1_s12104-014-9578-7.png' to 'fig1_s12104-014-9578-7.tif'
# Converted 'fig1_s12104-010-9283-0.png' to 'fig1_s12104-010-9283-0.tif'
# Converted 'fig1_s12104-016-9674-y.png' to 'fig1_s12104-016-9674-y.tif'
# Converted 'fig1_s12104-012-9417-7.png' to 'fig1_s12104-012-9417-7.tif'
# Converted 'fig1_s12104-010-9281-2.png' to 'fig1_s12104-010-9281-2.tif'
# Converted 'fig1_s12104-015-9613-3.png' to 'fig1_s12104-015-9613-3.tif'
# Converted 'fig1_s12104-016-9713-8.png' to 'fig1_s12104-016-9713-8.tif'
# Converted 'fig1_s12104-011-9293-6.png' to 'fig1_s12104-011-9293-6.tif'
# Converted 'fig1_s12104-010-9245-6.png' to 'fig1_s12104-010-9245-6.tif'
# Converted 'fig1_s12104-010-9258-1.png' to 'fig1_s12104-010-9258-1.tif'
# Converted 'fig1_s12104-013-9509-z.png' to 'fig1_s12104-013-9509-z.tif'
# Converted 'fig1_s12104-007-9018-z.png' to 'fig1_s12104-007-9018-z.tif'
# Converted 'fig1_s12104-016-9692-9.png' to 'fig1_s12104-016-9692-9.tif'
# Converted 'fig1_s12104-017-9755-6.png' to 'fig1_s12104-017-9755-6.tif'
# Converted 'fig1_s12104-015-9649-4.png' to 'fig1_s12104-015-9649-4.tif'
# Converted 'fig1_s12104-018-9840-5.png' to 'fig1_s12104-018-9840-5.tif'
# Converted 'fig1_s12104-015-9595-1.png' to 'fig1_s12104-015-9595-1.tif'
# Converted 'fig1_s12104-018-9823-6.png' to 'fig1_s12104-018-9823-6.tif'
# Converted 'fig1_s12104-019-09909-7.png' to 'fig1_s12104-019-09909-7.tif'
# Converted 'fig1_s12104-020-09946-7.png' to 'fig1_s12104-020-09946-7.tif'
# Converted 'fig1_s12104-019-09884-z.png' to 'fig1_s12104-019-09884-z.tif'
# Converted 'fig1_s12104-011-9297-2.png' to 'fig1_s12104-011-9297-2.tif'
# Converted 'fig1_s12104-019-09923-9.png' to 'fig1_s12104-019-09923-9.tif'
# Converted 'fig1_s12104-011-9316-3.png' to 'fig1_s12104-011-9316-3.tif'
# Converted 'fig1_s12104-011-9338-x.png' to 'fig1_s12104-011-9338-x.tif'
# Converted 'fig1_s12104-008-9085-9.png' to 'fig1_s12104-008-9085-9.tif'
# Converted 'fig1_s12104-016-9678-7.png' to 'fig1_s12104-016-9678-7.tif'
# Converted 'fig1_s12104-018-9844-1.png' to 'fig1_s12104-018-9844-1.tif'
# Converted 'fig1_s12104-010-9276-z.png' to 'fig1_s12104-010-9276-z.tif'
# Converted 'fig1_s12104-017-9775-2.png' to 'fig1_s12104-017-9775-2.tif'
# Converted 'fig1_s12104-019-09886-x.png' to 'fig1_s12104-019-09886-x.tif'
# Converted 'fig1_s12104-013-9538-7.png' to 'fig1_s12104-013-9538-7.tif'
# Converted 'fig1_s12104-017-9730-2.png' to 'fig1_s12104-017-9730-2.tif'
# Converted 'fig1_s12104-015-9608-0.png' to 'fig1_s12104-015-9608-0.tif'
# Converted 'fig1_s12104-011-9351-0.png' to 'fig1_s12104-011-9351-0.tif'
# Converted 'fig1_s12104-010-9250-9.png' to 'fig1_s12104-010-9250-9.tif'
# Converted 'fig1_s12104-016-9676-9.png' to 'fig1_s12104-016-9676-9.tif'
# Converted 'fig1_s12104-017-9777-0.png' to 'fig1_s12104-017-9777-0.tif'
# Converted 'fig1_s12104-007-9009-0.png' to 'fig1_s12104-007-9009-0.tif'
# Converted 'fig1_s12104-008-9104-x.png' to 'fig1_s12104-008-9104-x.tif'
# Converted 'fig1_s12104-018-9855-y.png' to 'fig1_s12104-018-9855-y.tif'
# Converted 'fig1_s12104-015-9619-x.png' to 'fig1_s12104-015-9619-x.tif'
# Converted 'fig1_s12104-016-9719-2.png' to 'fig1_s12104-016-9719-2.tif'
# Converted 'fig1_s12104-018-9860-1.png' to 'fig1_s12104-018-9860-1.tif'
# Converted 'fig1_s12104-020-09962-7.png' to 'fig1_s12104-020-09962-7.tif'
# Converted 'fig1_s12104-020-09979-y.png' to 'fig1_s12104-020-09979-y.tif'
# Converted 'fig1_s12104-014-9585-8.png' to 'fig1_s12104-014-9585-8.tif'
# Converted 'fig1_s12104-009-9199-8.png' to 'fig1_s12104-009-9199-8.tif'
# Converted 'fig1_s12104-007-9003-6.png' to 'fig1_s12104-007-9003-6.tif'
# Converted 'fig1_s12104-011-9299-0.png' to 'fig1_s12104-011-9299-0.tif'
# Converted 'fig1_s12104-011-9318-1.png' to 'fig1_s12104-011-9318-1.tif'
# Converted 'fig1_s12104-010-9219-8.png' to 'fig1_s12104-010-9219-8.tif'
# Converted 'fig1_s12104-020-10003-6.png' to 'fig1_s12104-020-10003-6.tif'
# Converted 'fig1_s12104-013-9462-x.png' to 'fig1_s12104-013-9462-x.tif'
# Converted 'fig1_s12104-013-9530-2.png' to 'fig1_s12104-013-9530-2.tif'
# Converted 'fig1_s12104-008-9081-0.png' to 'fig1_s12104-008-9081-0.tif'
# Converted 'fig1_s12104-020-09960-9.png' to 'fig1_s12104-020-09960-9.tif'
# Converted 'fig1_s12104-018-9805-8.png' to 'fig1_s12104-018-9805-8.tif'
# Converted 'fig1_s12104-008-9100-1.png' to 'fig1_s12104-008-9100-1.tif'
# Converted 'fig1_s12104-020-09948-5.png' to 'fig1_s12104-020-09948-5.tif'
# Converted 'fig1_s12104-007-9029-9.png' to 'fig1_s12104-007-9029-9.tif'
# Converted 'fig1_s12104-015-9602-6.png' to 'fig1_s12104-015-9602-6.tif'
# Converted 'fig1_s12104-010-9256-3.png' to 'fig1_s12104-010-9256-3.tif'
# Converted 'fig1_s12104-013-9475-5.png' to 'fig1_s12104-013-9475-5.tif'
# Converted 'fig1_s12104-017-9734-y.png' to 'fig1_s12104-017-9734-y.tif'
# Converted 'fig1_s12104-010-9213-1.png' to 'fig1_s12104-010-9213-1.tif'
# Converted 'fig1_s12104-009-9155-7.png' to 'fig1_s12104-009-9155-7.tif'
# Converted 'fig1_s12104-017-9780-5.png' to 'fig1_s12104-017-9780-5.tif'
# Converted 'fig1_s12104-014-9556-0.png' to 'fig1_s12104-014-9556-0.tif'
# Converted 'fig1_s12104-008-9113-9.png' to 'fig1_s12104-008-9113-9.tif'
# Converted 'fig1_s12104-010-9228-7.png' to 'fig1_s12104-010-9228-7.tif'
# Converted 'fig1_s12104-009-9193-1.png' to 'fig1_s12104-009-9193-1.tif'
# Converted 'fig1_s12104-010-9211-3.png' to 'fig1_s12104-010-9211-3.tif'
# Converted 'fig1_s12104-016-9704-9.png' to 'fig1_s12104-016-9704-9.tif'
# Converted 'fig1_s12104-018-9853-0.png' to 'fig1_s12104-018-9853-0.tif'
# Converted 'fig1_s12104-014-9550-6.png' to 'fig1_s12104-014-9550-6.tif'
# Converted 'fig1_s12104-012-9419-5.png' to 'fig1_s12104-012-9419-5.tif'
# Converted 'fig1_s12104-012-9391-0.png' to 'fig1_s12104-012-9391-0.tif'
# Converted 'fig1_s12104-011-9305-6.png' to 'fig1_s12104-011-9305-6.tif'
# Converted 'fig1_s12104-014-9552-4.png' to 'fig1_s12104-014-9552-4.tif'
# Converted 'fig1_s12104-011-9307-4.png' to 'fig1_s12104-011-9307-4.tif'
# Converted 'fig1_s12104-016-9689-4.png' to 'fig1_s12104-016-9689-4.tif'
# Converted 'fig1_s12104-010-9287-9.png' to 'fig1_s12104-010-9287-9.tif'
# Converted 'fig1_s12104-012-9439-1.png' to 'fig1_s12104-012-9439-1.tif'
# Converted 'fig1_s12104-018-9866-8.png' to 'fig1_s12104-018-9866-8.tif'
# Converted 'fig1_s12104-015-9652-9.png' to 'fig1_s12104-015-9652-9.tif'
# Converted 'fig1_s12104-012-9426-6.png' to 'fig1_s12104-012-9426-6.tif'
# Converted 'fig1_s12104-008-9119-3.png' to 'fig1_s12104-008-9119-3.tif'
# Converted 'fig1_s12104-007-9059-3.png' to 'fig1_s12104-007-9059-3.tif'
# Converted 'fig1_s12104-012-9397-7.png' to 'fig1_s12104-012-9397-7.tif'
# Converted 'fig1_s12104-009-9171-7.png' to 'fig1_s12104-009-9171-7.tif'
# Converted 'fig1_s12104-011-9325-2.png' to 'fig1_s12104-011-9325-2.tif'
# Converted 'fig1_s12104-009-9175-3.png' to 'fig1_s12104-009-9175-3.tif'
# Converted 'fig1_s12104-010-9226-9.png' to 'fig1_s12104-010-9226-9.tif'
# Converted 'fig2_s12104-018-9811-x.png' to 'fig2_s12104-018-9811-x.tif'
# Converted 'fig1_s12104-013-9495-1.png' to 'fig1_s12104-013-9495-1.tif'
# Converted 'fig1_s12104-014-9572-0.png' to 'fig1_s12104-014-9572-0.tif'
# Converted 'fig1_s12104-012-9415-9.png' to 'fig1_s12104-012-9415-9.tif'
# Converted 'fig1_s12104-008-9090-z.png' to 'fig1_s12104-008-9090-z.tif'
# Converted 'fig1_s12104-008-9092-x.png' to 'fig1_s12104-008-9092-x.tif'
# Converted 'fig1_s12104-012-9433-7.png' to 'fig1_s12104-012-9433-7.tif'
# Converted 'fig1_s12104-016-9690-y.png' to 'fig1_s12104-016-9690-y.tif'
# Converted 'fig1_s12104-009-9164-6.png' to 'fig1_s12104-009-9164-6.tif'
# Converted 'fig1_s12104-012-9411-0.png' to 'fig1_s12104-012-9411-0.tif'
# Converted 'fig1_s12104-008-9139-z.png' to 'fig1_s12104-008-9139-z.tif'
# Converted 'fig1_s12104-009-9197-x.png' to 'fig1_s12104-009-9197-x.tif'
# Converted 'fig1_s12104-010-9261-6.png' to 'fig1_s12104-010-9261-6.tif'
# Converted 'fig1_s12104-010-9263-4.png' to 'fig1_s12104-010-9263-4.tif'
# Converted 'fig1_s12104-012-9437-3.png' to 'fig1_s12104-012-9437-3.tif'
# Converted 'fig1_s12104-012-9399-5.png' to 'fig1_s12104-012-9399-5.tif'
# Converted 'fig1_s12104-014-9576-9.png' to 'fig1_s12104-014-9576-9.tif'
# Converted 'fig1_s12104-013-9477-3.png' to 'fig1_s12104-013-9477-3.tif'
# Converted 'fig1_s12104-018-9832-5.png' to 'fig1_s12104-018-9832-5.tif'
# Converted 'fig1_s12104-017-9746-7.png' to 'fig1_s12104-017-9746-7.tif'
# Converted 'fig1_s12104-012-9357-2.png' to 'fig1_s12104-012-9357-2.tif'
# Converted 'fig1_s12104-009-9168-2.png' to 'fig1_s12104-009-9168-2.tif'
# Converted 'fig1_s12104-013-9468-4.png' to 'fig1_s12104-013-9468-4.tif'
# Converted 'fig1_s12104-009-9148-6.png' to 'fig1_s12104-009-9148-6.tif'
# Converted 'fig1_s12104-020-09955-6.png' to 'fig1_s12104-020-09955-6.tif'
# Converted 'fig1_s12104-008-9126-4.png' to 'fig1_s12104-008-9126-4.tif'
# Converted 'fig1_s12104-010-9249-2.png' to 'fig1_s12104-010-9249-2.tif'
# Converted 'fig1_s12104-020-09993-0.png' to 'fig1_s12104-020-09993-0.tif'
# Converted 'fig1_s12104-013-9480-8.png' to 'fig1_s12104-013-9480-8.tif'
# Converted 'fig1_s12104-014-9567-x.png' to 'fig1_s12104-014-9567-x.tif'
# Converted 'fig1_s12104-020-09977-0.png' to 'fig1_s12104-020-09977-0.tif'
# Converted 'fig1_s12104-014-9565-z.png' to 'fig1_s12104-014-9565-z.tif'
# Converted 'fig1_s12104-013-9473-7.png' to 'fig1_s12104-013-9473-7.tif'
# Converted 'fig1_s12104-018-9801-z.png' to 'fig1_s12104-018-9801-z.tif'
# Converted 'fig1_s12104-017-9740-0.png' to 'fig1_s12104-017-9740-0.tif'
# Converted 'fig1_s12104-007-9066-4.png' to 'fig1_s12104-007-9066-4.tif'
# Converted 'fig1_s12104-018-09869-4.png' to 'fig1_s12104-018-09869-4.tif'
# Converted 'fig1_s12104-020-09930-1.png' to 'fig1_s12104-020-09930-1.tif'
# Converted 'fig1_s12104-010-9237-6.png' to 'fig1_s12104-010-9237-6.tif'
# Converted 'fig1_s12104-018-9862-z.png' to 'fig1_s12104-018-9862-z.tif'
# Converted 'fig1_s12104-010-9241-x.png' to 'fig1_s12104-010-9241-x.tif'
# Converted 'fig1_s12104-010-9254-5.png' to 'fig1_s12104-010-9254-5.tif'
# Converted 'fig1_s12104-010-9290-1.png' to 'fig1_s12104-010-9290-1.tif'
# Converted 'fig1_s12104-015-9635-x.png' to 'fig1_s12104-015-9635-x.tif'
# Converted 'fig1_s12104-015-9604-4.png' to 'fig1_s12104-015-9604-4.tif'
# Converted 'fig1_s12104-018-9798-3.png' to 'fig1_s12104-018-9798-3.tif'
# Converted 'fig1_s12104-015-9597-z.png' to 'fig1_s12104-015-9597-z.tif'
# Converted 'fig1_s12104-012-9402-1.png' to 'fig1_s12104-012-9402-1.tif'
# Converted 'fig1_s12104-008-9098-4.png' to 'fig1_s12104-008-9098-4.tif'
# Converted 'fig1_s12104-012-9384-z.png' to 'fig1_s12104-012-9384-z.tif'
# Converted 'fig1_s12104-019-09916-8.png' to 'fig1_s12104-019-09916-8.tif'
# Converted 'fig2_s12104-015-9610-6.png' to 'fig2_s12104-015-9610-6.tif'
# Converted 'fig1_s12104-013-9527-x.png' to 'fig1_s12104-013-9527-x.tif'
# Converted 'fig1_s12104-016-9717-4.png' to 'fig1_s12104-016-9717-4.tif'
# Converted 'fig1_s12104-012-9413-y.png' to 'fig1_s12104-012-9413-y.tif'
# Converted 'fig1_s12104-008-9094-8.png' to 'fig1_s12104-008-9094-8.tif'
# Converted 'fig1_s12104-024-10170-w.png' to 'fig1_s12104-024-10170-w.tif'
# Converted 'fig1_s12104-018-9846-z.png' to 'fig1_s12104-018-9846-z.tif'
# Converted 'fig1_s12104-019-09899-6.png' to 'fig1_s12104-019-09899-6.tif'
# Converted 'fig1_s12104-016-9702-y.png' to 'fig1_s12104-016-9702-y.tif'
# Converted 'fig1_s12104-013-9525-z.png' to 'fig1_s12104-013-9525-z.tif'
# Converted 'fig1_s12104-013-9514-2.png' to 'fig1_s12104-013-9514-2.tif'
# Converted 'fig1_s12104-019-09912-y.png' to 'fig1_s12104-019-09912-y.tif'
# Converted 'fig1_s12104-019-09882-1.png' to 'fig1_s12104-019-09882-1.tif'
# Converted 'fig1_s12104-016-9670-2.png' to 'fig1_s12104-016-9670-2.tif'
# Converted 'fig1_s12104-007-9005-4.png' to 'fig1_s12104-007-9005-4.tif'
# Converted 'fig1_s12104-015-9663-6.png' to 'fig1_s12104-015-9663-6.tif'
# Converted 'fig1_s12104-011-9355-9.png' to 'fig1_s12104-011-9355-9.tif'
# Converted 'fig1_s12104-018-9821-8.png' to 'fig1_s12104-018-9821-8.tif'
# Converted 'fig1_s12104-007-9051-y.png' to 'fig1_s12104-007-9051-y.tif'
# Converted 'fig1_s12104-012-9443-5.png' to 'fig1_s12104-012-9443-5.tif'
# Converted 'fig1_s12104-009-9160-x.png' to 'fig1_s12104-009-9160-x.tif'
# Converted 'fig1_s12104-013-9512-4.png' to 'fig1_s12104-013-9512-4.tif'
# Converted 'fig1_s12104-007-9007-2.png' to 'fig1_s12104-007-9007-2.tif'
# Converted 'fig1_s12104-008-9111-y.png' to 'fig1_s12104-008-9111-y.tif'
# Converted 'fig1_s12104-015-9650-y.png' to 'fig1_s12104-015-9650-y.tif'
# Converted 'fig1_s12104-010-9285-y.png' to 'fig1_s12104-010-9285-y.tif'
# Converted 'fig1_s12104-015-9633-z.png' to 'fig1_s12104-015-9633-z.tif'
# Converted 'fig1_s12104-018-9828-1.png' to 'fig1_s12104-018-9828-1.tif'
# Converted 'fig1_s12104-014-9551-5.png' to 'fig1_s12104-014-9551-5.tif'
# Converted 'fig1_s12104-019-09889-8.png' to 'fig1_s12104-019-09889-8.tif'
# Converted 'fig1_s12104-015-9651-x.png' to 'fig1_s12104-015-9651-x.tif'
# Converted 'fig1_s12104-017-9785-0.png' to 'fig1_s12104-017-9785-0.tif'
# Converted 'fig1_s12104-015-9607-1.png' to 'fig1_s12104-015-9607-1.tif'
# Converted 'fig1_s12104-018-9804-9.png' to 'fig1_s12104-018-9804-9.tif'
# Converted 'fig1_s12104-014-9584-9.png' to 'fig1_s12104-014-9584-9.tif'
# Converted 'fig1_s12104-008-9123-7.png' to 'fig1_s12104-008-9123-7.tif'
# Converted 'fig1_s12104-011-9354-x.png' to 'fig1_s12104-011-9354-x.tif'
# Converted 'fig1_s12104-020-10002-7.png' to 'fig1_s12104-020-10002-7.tif'
# Converted 'fig1_s12104-013-9476-4.png' to 'fig1_s12104-013-9476-4.tif'
# Converted 'fig1_s12104-007-9063-7.png' to 'fig1_s12104-007-9063-7.tif'
# Converted 'fig1_s12104-011-9298-1.png' to 'fig1_s12104-011-9298-1.tif'
# Converted 'fig1_s12104-018-9858-8.png' to 'fig1_s12104-018-9858-8.tif'
# Converted 'fig1_s12104-010-9253-6.png' to 'fig1_s12104-010-9253-6.tif'
# Converted 'fig1_s12104-016-9705-8.png' to 'fig1_s12104-016-9705-8.tif'
# Converted 'fig1_s12104-020-09961-8.png' to 'fig1_s12104-020-09961-8.tif'
# Converted 'fig1_s12104-019-09881-2.png' to 'fig1_s12104-019-09881-2.tif'
# Converted 'fig1_s12104-010-9218-9.png' to 'fig1_s12104-010-9218-9.tif'
# Converted 'fig1_s12104-019-09902-0.png' to 'fig1_s12104-019-09902-0.tif'
# Converted 'fig1_s12104-015-9662-7.png' to 'fig1_s12104-015-9662-7.tif'
# Converted 'fig1_s12104-020-09945-8.png' to 'fig1_s12104-020-09945-8.tif'
# Converted 'fig1_s12104-010-9225-x.png' to 'fig1_s12104-010-9225-x.tif'
# Converted 'fig1_s12104-010-9212-2.png' to 'fig1_s12104-010-9212-2.tif'
# Converted 'fig1_s12104-008-9127-3.png' to 'fig1_s12104-008-9127-3.tif'
# Converted 'fig1_s12104-013-9469-3.png' to 'fig1_s12104-013-9469-3.tif'
# Converted 'fig1_s12104-013-9474-6.png' to 'fig1_s12104-013-9474-6.tif'
# Converted 'fig1_s12104-017-9739-6.png' to 'fig1_s12104-017-9739-6.tif'
# Converted 'fig1_s12104-009-9172-6.png' to 'fig1_s12104-009-9172-6.tif'
# Converted 'fig1_s12104-018-9820-9.png' to 'fig1_s12104-018-9820-9.tif'
# Converted 'fig1_s12104-014-9571-1.png' to 'fig1_s12104-014-9571-1.tif'
# Converted 'fig1_s12104-012-9438-2.png' to 'fig1_s12104-012-9438-2.tif'
# Converted 'fig1_s12104-013-9494-2.png' to 'fig1_s12104-013-9494-2.tif'
# Converted 'fig1_s12104-018-9839-y.png' to 'fig1_s12104-018-9839-y.tif'
# Converted 'fig1_s12104-011-9311-8.png' to 'fig1_s12104-011-9311-8.tif'
# Converted 'fig1_s12104-008-9091-y.png' to 'fig1_s12104-008-9091-y.tif'
# Converted 'fig1_s12104-015-9640-0.png' to 'fig1_s12104-015-9640-0.tif'
# Converted 'fig1_s12104-013-9496-0.png' to 'fig1_s12104-013-9496-0.tif'
# Converted 'fig1_s12104-010-9273-2.png' to 'fig1_s12104-010-9273-2.tif'
# Converted 'fig1_s12104-012-9425-7.png' to 'fig1_s12104-012-9425-7.tif'
# Converted 'fig1_s12104-013-9492-4.png' to 'fig1_s12104-013-9492-4.tif'
# Converted 'fig1_s12104-007-9002-7.png' to 'fig1_s12104-007-9002-7.tif'
# Converted 'fig1_s12104-013-9490-6.png' to 'fig1_s12104-013-9490-6.tif'
# Converted 'fig1_s12104-017-9796-x.png' to 'fig1_s12104-017-9796-x.tif'
# Converted 'fig1_s12104-014-9588-5.png' to 'fig1_s12104-014-9588-5.tif'
# Converted 'fig1_s12104-010-9279-9.png' to 'fig1_s12104-010-9279-9.tif'
# Converted 'fig1_s12104-007-9028-x.png' to 'fig1_s12104-007-9028-x.tif'
# Converted 'fig1_s12104-013-9463-9.png' to 'fig1_s12104-013-9463-9.tif'
# Converted 'fig1_s12104-009-9176-2.png' to 'fig1_s12104-009-9176-2.tif'
# Converted 'fig1_s12104-018-9816-5.png' to 'fig1_s12104-018-9816-5.tif'
# Converted 'fig1_s12104-014-9581-z.png' to 'fig1_s12104-014-9581-z.tif'
# Converted 'fig1_s12104-013-9457-7.png' to 'fig1_s12104-013-9457-7.tif'
# Converted 'fig1_s12104-013-9493-3.png' to 'fig1_s12104-013-9493-3.tif'
# Converted 'fig1_s12104-012-9408-8.png' to 'fig1_s12104-012-9408-8.tif'
# Converted 'fig1_s12104-015-9637-8.png' to 'fig1_s12104-015-9637-8.tif'
# Converted 'fig1_s12104-007-9034-z.png' to 'fig1_s12104-007-9034-z.tif'
# Converted 'fig1_s12104-017-9766-3.png' to 'fig1_s12104-017-9766-3.tif'
# Converted 'fig1_s12104-010-9243-8.png' to 'fig1_s12104-010-9243-8.tif'
# Converted 'fig1_s12104-009-9146-8.png' to 'fig1_s12104-009-9146-8.tif'
# Converted 'fig1_s12104-008-9138-0.png' to 'fig1_s12104-008-9138-0.tif'
# Converted 'fig1_s12104-010-9240-y.png' to 'fig1_s12104-010-9240-y.tif'
# Converted 'fig1_s12104-018-9837-0.png' to 'fig1_s12104-018-9837-0.tif'
# Converted 'fig1_s12104-018-9831-6.png' to 'fig1_s12104-018-9831-6.tif'
# Converted 'fig1_s12104-013-9498-y.png' to 'fig1_s12104-013-9498-y.tif'
# Converted 'fig1_s12104-019-09896-9.png' to 'fig1_s12104-019-09896-9.tif'
# Converted 'fig1_s12104-012-9412-z.png' to 'fig1_s12104-012-9412-z.tif'
# Converted 'fig1_s12104-020-09931-0.png' to 'fig1_s12104-020-09931-0.tif'
# Converted 'fig1_s12104-010-9214-0.png' to 'fig1_s12104-010-9214-0.tif'
# Converted 'fig1_s12104-019-09894-x.png' to 'fig1_s12104-019-09894-x.tif'
# Converted 'fig1_s12104-014-9566-y.png' to 'fig1_s12104-014-9566-y.tif'
# Converted 'fig1_s12104-007-9024-1.png' to 'fig1_s12104-007-9024-1.tif'
# Converted 'fig1_s12104-008-9114-8.png' to 'fig1_s12104-008-9114-8.tif'
# Converted 'fig1_s12104-018-9817-4.png' to 'fig1_s12104-018-9817-4.tif'
# Converted 'fig1_s12104-015-9638-7.png' to 'fig1_s12104-015-9638-7.tif'
# Converted 'fig1_s12104-012-9378-x.png' to 'fig1_s12104-012-9378-x.tif'
# Converted 'fig1_s12104-024-10193-3.png' to 'fig1_s12104-024-10193-3.tif'
# Converted 'fig1_s12104-020-09992-1.png' to 'fig1_s12104-020-09992-1.tif'
# Converted 'fig1_s12104-017-9747-6.png' to 'fig1_s12104-017-9747-6.tif'
# Converted 'fig1_s12104-019-09919-5.png' to 'fig1_s12104-019-09919-5.tif'
# Converted 'fig1_s12104-010-9248-3.png' to 'fig1_s12104-010-9248-3.tif'
# Converted 'fig1_s12104-020-09954-7.png' to 'fig1_s12104-020-09954-7.tif'
# Converted 'fig1_s12104-020-09956-5.png' to 'fig1_s12104-020-09956-5.tif'
# Converted 'fig1_s12104-018-9815-6.png' to 'fig1_s12104-018-9815-6.tif'
# Converted 'fig1_s12104-020-09935-w.png' to 'fig1_s12104-020-09935-w.tif'
# Converted 'fig1_s12104-017-9728-9.png' to 'fig1_s12104-017-9728-9.tif'
# Converted 'fig1_s12104-020-09990-3.png' to 'fig1_s12104-020-09990-3.tif'
# Converted 'fig1_s12104-012-9442-6.png' to 'fig1_s12104-012-9442-6.tif'
# Converted 'fig1_s12104-017-9763-6.png' to 'fig1_s12104-017-9763-6.tif'
# Converted 'fig1_s12104-012-9372-3.png' to 'fig1_s12104-012-9372-3.tif'
# Converted 'fig1_s12104-014-9582-y.png' to 'fig1_s12104-014-9582-y.tif'
# Converted 'fig1_s12104-020-09976-1.png' to 'fig1_s12104-020-09976-1.tif'
# Converted 'fig1_s12104-018-9847-y.png' to 'fig1_s12104-018-9847-y.tif'
# Converted 'fig1_s12104-019-09908-8.png' to 'fig1_s12104-019-09908-8.tif'
# Converted 'fig1_s12104-012-9446-2.png' to 'fig1_s12104-012-9446-2.tif'
# Converted 'fig1_s12104-019-09915-9.png' to 'fig1_s12104-019-09915-9.tif'
# Converted 'fig1_s12104-010-9284-z.png' to 'fig1_s12104-010-9284-z.tif'
# Converted 'fig1_s12104-011-9320-7.png' to 'fig1_s12104-011-9320-7.tif'
# Converted 'fig1_s12104-016-9709-4.png' to 'fig1_s12104-016-9709-4.tif'
# Converted 'fig1_s12104-011-9343-0.png' to 'fig1_s12104-011-9343-0.tif'
# Converted 'fig1_s12104-015-9623-1.png' to 'fig1_s12104-015-9623-1.tif'
# Converted 'fig1_s12104-012-9374-1.png' to 'fig1_s12104-012-9374-1.tif'
# Converted 'fig1_s12104-019-09922-w.png' to 'fig1_s12104-019-09922-w.tif'
# Converted 'fig1_s12104-020-09987-y.png' to 'fig1_s12104-020-09987-y.tif'
# Converted 'fig1_s12104-015-9653-8.png' to 'fig1_s12104-015-9653-8.tif'
# Converted 'fig1_s12104-013-9511-5.png' to 'fig1_s12104-013-9511-5.tif'
# Converted 'fig1_s12104-020-09926-x.png' to 'fig1_s12104-020-09926-x.tif'
# Converted 'fig1_s12104-011-9322-5.png' to 'fig1_s12104-011-9322-5.tif'
# Converted 'fig1_s12104-007-9050-z.png' to 'fig1_s12104-007-9050-z.tif'
# Converted 'fig1_s12104-007-9052-x.png' to 'fig1_s12104-007-9052-x.tif'
# Converted 'fig1_s12104-008-9099-3.png' to 'fig1_s12104-008-9099-3.tif'
# Converted 'fig2_s12104-017-9742-y.png' to 'fig2_s12104-017-9742-y.tif'
# Converted 'fig1_s12104-017-9735-x.png' to 'fig1_s12104-017-9735-x.tif'
# Converted 'fig1_s12104-015-9605-3.png' to 'fig1_s12104-015-9605-3.tif'
# Converted 'fig1_s12104-017-9781-4.png' to 'fig1_s12104-017-9781-4.tif'
# Converted 'fig1_s12104-009-9143-y.png' to 'fig1_s12104-009-9143-y.tif'
# Converted 'fig1_s12104-012-9414-x.png' to 'fig1_s12104-012-9414-x.tif'
# Converted 'fig1_s12104-008-9140-6.png' to 'fig1_s12104-008-9140-6.tif'
# Converted 'fig1_s12104-015-9601-7.png' to 'fig1_s12104-015-9601-7.tif'
# Converted 'fig1_s12104-018-9852-1.png' to 'fig1_s12104-018-9852-1.tif'
# Converted 'fig1_s12104-010-9229-6.png' to 'fig1_s12104-010-9229-6.tif'
# Converted 'fig1_s12104-012-9389-7.png' to 'fig1_s12104-012-9389-7.tif'
# Converted 'fig1_s12104-017-9752-9.png' to 'fig1_s12104-017-9752-9.tif'
# Converted 'fig1_s12104-009-9169-1.png' to 'fig1_s12104-009-9169-1.tif'
# Converted 'fig1_s12104-016-9695-6.png' to 'fig1_s12104-016-9695-6.tif'
# Converted 'fig1_s12104-009-9187-z.png' to 'fig1_s12104-009-9187-z.tif'
# Converted 'fig1_s12104-012-9401-2.png' to 'fig1_s12104-012-9401-2.tif'
# Converted 'fig1_s12104-008-9130-8.png' to 'fig1_s12104-008-9130-8.tif'
# Converted 'fig1_s12104-016-9714-7.png' to 'fig1_s12104-016-9714-7.tif'
# Converted 'fig1_s12104-009-9174-4.png' to 'fig1_s12104-009-9174-4.tif'
# Converted 'fig1_s12104-019-09898-7.png' to 'fig1_s12104-019-09898-7.tif'
# Converted 'fig1_s12104-014-9559-x.png' to 'fig1_s12104-014-9559-x.tif'
# Converted 'fig1_s12104-016-9697-4.png' to 'fig1_s12104-016-9697-4.tif'
# Converted 'fig1_s12104-016-9703-x.png' to 'fig1_s12104-016-9703-x.tif'
# Converted 'fig1_s12104-012-9403-0.png' to 'fig1_s12104-012-9403-0.tif'
# Converted 'fig1_s12104-010-9275-0.png' to 'fig1_s12104-010-9275-0.tif'
# Converted 'fig1_s12104-007-9035-y.png' to 'fig1_s12104-007-9035-y.tif'
# Converted 'fig1_s12104-016-9716-5.png' to 'fig1_s12104-016-9716-5.tif'
# Converted 'fig1_s12104-009-9145-9.png' to 'fig1_s12104-009-9145-9.tif'
# Converted 'fig1_s12104-009-9149-5.png' to 'fig1_s12104-009-9149-5.tif'
# Converted 'fig1_s12104-010-9255-4.png' to 'fig1_s12104-010-9255-4.tif'
# Converted 'fig1_s12104-007-9004-5.png' to 'fig1_s12104-007-9004-5.tif'
# Converted 'fig1_s12104-010-9236-7.png' to 'fig1_s12104-010-9236-7.tif'
# Converted 'fig1_s12104-009-9190-4.png' to 'fig1_s12104-009-9190-4.tif'
# Converted 'fig1_s12104-009-9161-9.png' to 'fig1_s12104-009-9161-9.tif'
# Converted 'fig1_s12104-010-9271-4.png' to 'fig1_s12104-010-9271-4.tif'
# Converted 'fig1_s12104-008-9125-5.png' to 'fig1_s12104-008-9125-5.tif'
# Converted 'fig1_s12104-007-9065-5.png' to 'fig1_s12104-007-9065-5.tif'
# Converted 'fig1_s12104-007-9078-0.png' to 'fig1_s12104-007-9078-0.tif'
# --- PNG to .tif conversion finished ---
# Successfully converted 607 PNG image(s) to .tif.
# ----------------------------------------
#
#
# --- Starting deletion of non-.tif files in folder: /content/drive/MyDrive/BMRB_images ---
# WARNING: This will delete all files except those with the .tif extension.
# Deleted: fig1_s12104-016-9668-9.png
# Deleted: fig1_s12104-013-9478-2.png
# Deleted: fig1_s12104-012-9383-0.png
# Deleted: fig1_s12104-007-9072-6.png
# Deleted: fig1_s12104-017-9726-y.png
# Deleted: fig1_s12104-012-9423-9.png
# Deleted: fig1_s12104-010-9238-5.png
# Deleted: fig1_s12104-008-9136-2.png
# Deleted: fig1_s12104-015-9642-y.png
# Deleted: fig1_s12104-011-9345-y.png
# Deleted: fig1_s12104-014-9573-z.png
# Deleted: fig1_s12104-018-9824-5.png
# Deleted: fig1_s12104-015-9598-y.png
# Deleted: fig1_s12104-013-9483-5.png
# Deleted: fig1_s12104-013-9481-7.png
# Deleted: fig1_s12104-012-9436-4.png
# Deleted: fig1_s12104-012-9365-2.png
# Deleted: fig1_s12104-009-9167-3.png
# Deleted: fig1_s12104-014-9562-2.png
# Deleted: fig1_s12104-010-9209-x.png
# Deleted: fig1_s12104-013-9472-8.png
# Deleted: fig1_s12104-013-9467-5.png
# Deleted: fig1_s12104-014-9542-6.png
# Deleted: fig1_s12104-008-9116-6.png
# Deleted: fig1_s12104-013-9465-7.png
# Deleted: fig1_s12104-012-9409-7.png
# Deleted: fig1_s12104-013-9487-1.png
# Deleted: fig1_s12104-011-9335-0.png
# Deleted: fig1_s12104-008-9082-z.png
# Deleted: fig1_s12104-011-9300-y.png
# Deleted: fig1_s12104-012-9381-2.png
# Deleted: fig1_s12104-009-9147-7.png
# Deleted: fig1_s12104-011-9331-4.png
# Deleted: fig1_s12104-012-9429-3.png
# Deleted: fig1_s12104-014-9568-9.png
# Deleted: fig1_s12104-012-9367-0.png
# Deleted: fig1_s12104-017-9787-y.png
# Deleted: fig1_s12104-010-9246-5.png
# Deleted: fig1_s12104-020-09927-w.png
# Deleted: fig1_s12104-019-09907-9.png
# Deleted: fig1_s12104-016-9698-3.png
# Deleted: fig1_s12104-012-9410-1.png
# Deleted: fig1_s12104-016-9710-y.png
# Deleted: fig1_s12104-017-9791-2.png
# Deleted: fig1_s12104-018-9819-2.png
# Deleted: fig1_s12104-016-9691-x.png
# Deleted: fig1_s12104-010-9262-5.png
# Deleted: fig1_s12104-010-9216-y.png
# Deleted: fig1_s12104-010-9260-7.png
# Deleted: fig1_s12104-014-9577-8.png
# Deleted: fig1_s12104-010-9266-1.png
# Deleted: .DS_Store
# Deleted: fig1_s12104-016-9707-6.png
# Deleted: fig1_s12104-017-9732-0.png
# Deleted: fig1_s12104-007-9011-6.png
# Deleted: fig1_s12104-008-9088-6.png
# Deleted: fig1_s12104-008-9095-7.png
# Deleted: fig1_s12104-017-9769-0.png
# Deleted: fig1_s12104-012-9452-4.png
# Deleted: fig1_s12104-012-9394-x.png
# Deleted: fig1_s12104-016-9686-7.png
# Deleted: fig1_s12104-018-9856-x.png
# Deleted: fig1_s12104-017-9731-1.png
# Deleted: fig1_s12104-019-09890-1.png
# Deleted: fig1_s12104-007-9013-4.png
# Deleted: fig1_s12104-011-9302-9.png
# Deleted: fig1_s12104-013-9506-2.png
# Deleted: fig1_s12104-007-9015-2.png
# Deleted: fig1_s12104-008-9097-5.png
# Deleted: fig1_s12104-017-9773-4.png
# Deleted: fig1_s12104-012-9360-7.png
# Deleted: fig1_s12104-012-9448-0.png
# Deleted: fig1_s12104-007-9017-0.png
# Deleted: fig1_s12104-011-9347-9.png
# Deleted: fig1_s12104-020-09994-z.png
# Deleted: fig1_s12104-013-9507-1.png
# Deleted: fig1_s12104-012-9392-z.png
# Deleted: fig1_s12104-017-9776-1.png
# Deleted: fig1_s12104-018-09870-x.png
# Deleted: fig1_s12104-015-9654-7.png
# Deleted: fig1_s12104-015-9610-6.png
# Deleted: fig1_s12104-015-9657-4.png
# Deleted: fig1_s12104-007-9033-0.png
# Deleted: fig1_s12104-016-9673-z.png
# Deleted: fig1_s12104-017-9749-4.png
# Deleted: fig1_s12104-015-9612-4.png
# Deleted: fig1_s12104-023-10159-x.png
# Deleted: fig1_s12104-012-9405-y.png
# Deleted: fig1_s12104-017-9761-8.png
# Deleted: fig1_s12104-020-09963-6.png
# Deleted: fig1_s12104-017-9770-7.png
# Deleted: fig1_s12104-015-9660-9.png
# Deleted: fig1_s12104-008-9086-8.png
# Deleted: fig1_s12104-015-9616-0.png
# Deleted: fig1_s12104-012-9376-z.png
# Deleted: fig1_s12104-013-9528-9.png
# Deleted: fig1_s12104-015-9614-2.png
# Deleted: fig1_s12104-016-9725-4.png
# Deleted: fig1_s12104-019-09917-7.png
# Deleted: fig1_s12104-008-9105-9.png
# Deleted: fig1_s12104-009-9152-x.png
# Deleted: fig1_s12104-009-9201-5.png
# Deleted: fig1_s12104-019-09904-y.png
# Deleted: fig1_s12104-020-09943-w.png
# Deleted: fig1_s12104-011-9294-5.png
# Deleted: fig1_s12104-019-09874-1.png
# Deleted: fig1_s12104-020-09933-y.png
# Deleted: fig1_s12104-018-9849-9.png
# Deleted: fig1_s12104-010-9268-z.png
# Deleted: fig1_s12104-015-9644-9.png
# Deleted: fig1_s12104-018-9806-7.png
# Deleted: fig1_s12104-007-9019-y.png
# Deleted: fig1_s12104-009-9203-3.png
# Deleted: fig1_s12104-009-9154-8.png
# Deleted: fig1_s12104-013-9489-z.png
# Deleted: fig1_s12104-010-9259-0.png
# Deleted: fig1_s12104-013-9510-6.png
# Deleted: fig1_s12104-007-9074-4.png
# Deleted: fig1_s12104-014-9554-2.png
# Deleted: fig1_s12104-008-9087-7.png
# Deleted: fig1_s12104-015-9648-5.png
# ...
# fig1_s12104-007-9033-0.tif
# fig1_s12104-007-9034-z.tif
# fig1_s12104-007-9035-y.tif
# fig1_s12104-007-9038-8.tif
# fig1_s12104-007-9045-9.tif
# fig1_s12104-007-9048-6.tif
# fig1_s12104-007-9050-z.tif
# fig1_s12104-007-9051-y.tif
# fig1_s12104-007-9052-x.tif
# fig1_s12104-007-9055-7.tif
# fig1_s12104-007-9057-5.tif
# fig1_s12104-007-9059-3.tif
# fig1_s12104-007-9061-9.tif
# fig1_s12104-007-9063-7.tif
# fig1_s12104-007-9065-5.tif
# fig1_s12104-007-9066-4.tif
# fig1_s12104-007-9068-2.tif
# fig1_s12104-007-9071-7.tif
# fig1_s12104-007-9072-6.tif
# fig1_s12104-007-9073-5.tif
# fig1_s12104-007-9074-4.tif
# fig1_s12104-007-9075-3.tif
# fig1_s12104-007-9078-0.tif
# fig1_s12104-008-9079-7.tif
# fig1_s12104-008-9081-0.tif
# fig1_s12104-008-9082-z.tif
# fig1_s12104-008-9084-x.tif
# fig1_s12104-008-9085-9.tif
# fig1_s12104-008-9086-8.tif
# fig1_s12104-008-9087-7.tif
# fig1_s12104-008-9088-6.tif
# fig1_s12104-008-9090-z.tif
# fig1_s12104-008-9091-y.tif
# fig1_s12104-008-9092-x.tif
# fig1_s12104-008-9094-8.tif
# fig1_s12104-008-9095-7.tif
# fig1_s12104-008-9097-5.tif
# fig1_s12104-008-9098-4.tif
# fig1_s12104-008-9099-3.tif
# fig1_s12104-008-9100-1.tif
# fig1_s12104-008-9102-z.tif
# fig1_s12104-008-9104-x.tif
# fig1_s12104-008-9105-9.tif
# fig1_s12104-008-9107-7.tif
# fig1_s12104-008-9108-6.tif
# fig1_s12104-008-9111-y.tif
# fig1_s12104-008-9113-9.tif
# fig1_s12104-008-9114-8.tif
# fig1_s12104-008-9116-6.tif
# fig1_s12104-008-9117-5.tif
# fig1_s12104-008-9119-3.tif
# fig1_s12104-008-9123-7.tif
# fig1_s12104-008-9125-5.tif
# fig1_s12104-008-9126-4.tif
# fig1_s12104-008-9127-3.tif
# fig1_s12104-008-9128-2.tif
# fig1_s12104-008-9130-8.tif
# fig1_s12104-008-9131-7.tif
# fig1_s12104-008-9133-5.tif
# fig1_s12104-008-9134-4.tif
# fig1_s12104-008-9136-2.tif
# fig1_s12104-008-9137-1.tif
# fig1_s12104-008-9138-0.tif
# fig1_s12104-008-9139-z.tif
# fig1_s12104-008-9140-6.tif
# fig1_s12104-008-9141-5.tif
# fig1_s12104-009-9143-y.tif
# fig1_s12104-009-9145-9.tif
# fig1_s12104-009-9146-8.tif
# fig1_s12104-009-9147-7.tif
# fig1_s12104-009-9148-6.tif
# fig1_s12104-009-9149-5.tif
# fig1_s12104-009-9151-y.tif
# fig1_s12104-009-9152-x.tif
# fig1_s12104-009-9153-9.tif
# fig1_s12104-009-9154-8.tif
# fig1_s12104-009-9155-7.tif
# fig1_s12104-009-9158-4.tif
# fig1_s12104-009-9160-x.tif
# fig1_s12104-009-9161-9.tif
# fig1_s12104-009-9164-6.tif
# fig1_s12104-009-9165-5.tif
# fig1_s12104-009-9167-3.tif
# fig1_s12104-009-9168-2.tif
# fig1_s12104-009-9169-1.tif
# fig1_s12104-009-9170-8.tif
# fig1_s12104-009-9171-7.tif
# fig1_s12104-009-9172-6.tif
# fig1_s12104-009-9174-4.tif
# fig1_s12104-009-9175-3.tif
# fig1_s12104-009-9176-2.tif
# fig1_s12104-009-9181-5.tif
# fig1_s12104-009-9182-4.tif
# fig1_s12104-009-9184-2.tif
# fig1_s12104-009-9185-1.tif
# fig1_s12104-009-9187-z.tif
# fig1_s12104-009-9188-y.tif
# fig1_s12104-009-9190-4.tif
# fig1_s12104-009-9193-1.tif
# fig1_s12104-009-9195-z.tif
# fig1_s12104-009-9197-x.tif
# fig1_s12104-009-9199-8.tif
# fig1_s12104-009-9201-5.tif
# fig1_s12104-009-9202-4.tif
# fig1_s12104-009-9203-3.tif
# fig1_s12104-009-9204-2.tif
# fig1_s12104-009-9206-0.tif
# fig1_s12104-010-9207-z.tif
# fig1_s12104-010-9209-x.tif
# fig1_s12104-010-9211-3.tif
# fig1_s12104-010-9212-2.tif
# fig1_s12104-010-9213-1.tif
# fig1_s12104-010-9214-0.tif
# fig1_s12104-010-9216-y.tif
# fig1_s12104-010-9218-9.tif
# fig1_s12104-010-9219-8.tif
# fig1_s12104-010-9220-2.tif
# fig1_s12104-010-9225-x.tif
# fig1_s12104-010-9226-9.tif
# fig1_s12104-010-9228-7.tif
# fig1_s12104-010-9229-6.tif
# fig1_s12104-010-9232-y.tif
# fig1_s12104-010-9235-8.tif
# fig1_s12104-010-9236-7.tif
# fig1_s12104-010-9237-6.tif
# fig1_s12104-010-9238-5.tif
# fig1_s12104-010-9240-y.tif
# fig1_s12104-010-9241-x.tif
# fig1_s12104-010-9243-8.tif
# fig1_s12104-010-9244-7.tif
# fig1_s12104-010-9245-6.tif
# fig1_s12104-010-9246-5.tif
# fig1_s12104-010-9248-3.tif
# fig1_s12104-010-9249-2.tif
# fig1_s12104-010-9250-9.tif
# fig1_s12104-010-9251-8.tif
# fig1_s12104-010-9253-6.tif
# fig1_s12104-010-9254-5.tif
# fig1_s12104-010-9255-4.tif
# fig1_s12104-010-9256-3.tif
# fig1_s12104-010-9258-1.tif
# fig1_s12104-010-9259-0.tif
# fig1_s12104-010-9260-7.tif
# fig1_s12104-010-9261-6.tif
# fig1_s12104-010-9262-5.tif
# fig1_s12104-010-9263-4.tif
# fig1_s12104-010-9266-1.tif
# fig1_s12104-010-9267-0.tif
# fig1_s12104-010-9268-z.tif
# fig1_s12104-010-9269-y.tif
# fig1_s12104-010-9271-4.tif
# fig1_s12104-010-9273-2.tif
# fig1_s12104-010-9275-0.tif
# fig1_s12104-010-9276-z.tif
# fig1_s12104-010-9277-y.tif
# fig1_s12104-010-9279-9.tif
# fig1_s12104-010-9280-3.tif
# fig1_s12104-010-9281-2.tif
# fig1_s12104-010-9282-1.tif
# fig1_s12104-010-9283-0.tif
# fig1_s12104-010-9284-z.tif
# fig1_s12104-010-9285-y.tif
# fig1_s12104-010-9287-9.tif
# fig1_s12104-010-9288-8.tif
# fig1_s12104-010-9290-1.tif
# fig1_s12104-011-9293-6.tif
# fig1_s12104-011-9294-5.tif
# fig1_s12104-011-9296-3.tif
# fig1_s12104-011-9297-2.tif
# fig1_s12104-011-9298-1.tif
# fig1_s12104-011-9299-0.tif
# fig1_s12104-011-9300-y.tif
# fig1_s12104-011-9301-x.tif
# fig1_s12104-011-9302-9.tif
# fig1_s12104-011-9303-8.tif
# fig1_s12104-011-9305-6.tif
# fig1_s12104-011-9307-4.tif
# fig1_s12104-011-9309-2.tif
# fig1_s12104-011-9311-8.tif
# fig1_s12104-011-9316-3.tif
# fig1_s12104-011-9317-2.tif
# fig1_s12104-011-9318-1.tif
# fig1_s12104-011-9320-7.tif
# fig1_s12104-011-9322-5.tif
# fig1_s12104-011-9325-2.tif
# fig1_s12104-011-9331-4.tif
# fig1_s12104-011-9333-2.tif
# fig1_s12104-011-9334-1.tif
# fig1_s12104-011-9335-0.tif
# fig1_s12104-011-9338-x.tif
# fig1_s12104-011-9339-9.tif
# fig1_s12104-011-9343-0.tif
# fig1_s12104-011-9345-y.tif
# fig1_s12104-011-9346-x.tif
# fig1_s12104-011-9347-9.tif
# fig1_s12104-011-9351-0.tif
# fig1_s12104-011-9354-x.tif
# fig1_s12104-011-9355-9.tif
# fig1_s12104-012-9357-2.tif
# fig1_s12104-012-9359-0.tif
# fig1_s12104-012-9360-7.tif
# fig1_s12104-012-9362-5.tif
# fig1_s12104-012-9365-2.tif
# fig1_s12104-012-9367-0.tif
# fig1_s12104-012-9372-3.tif
# fig1_s12104-012-9374-1.tif
# fig1_s12104-012-9376-z.tif
# fig1_s12104-012-9378-x.tif
# fig1_s12104-012-9380-3.tif
# fig1_s12104-012-9381-2.tif
# fig1_s12104-012-9382-1.tif
# fig1_s12104-012-9383-0.tif
# fig1_s12104-012-9384-z.tif
# fig1_s12104-012-9388-8.tif
# fig1_s12104-012-9389-7.tif
# fig1_s12104-012-9391-0.tif
# fig1_s12104-012-9392-z.tif
# fig1_s12104-012-9393-y.tif
# fig1_s12104-012-9394-x.tif
# fig1_s12104-012-9396-8.tif
# fig1_s12104-012-9397-7.tif
# fig1_s12104-012-9398-6.tif
# fig1_s12104-012-9399-5.tif
# fig1_s12104-012-9401-2.tif
# fig1_s12104-012-9402-1.tif
# fig1_s12104-012-9403-0.tif
# fig1_s12104-012-9404-z.tif
# fig1_s12104-012-9405-y.tif
# fig1_s12104-012-9406-x.tif
# fig1_s12104-012-9408-8.tif
# fig1_s12104-012-9409-7.tif
# fig1_s12104-012-9410-1.tif
# fig1_s12104-012-9411-0.tif
# fig1_s12104-012-9412-z.tif
# fig1_s12104-012-9413-y.tif
# fig1_s12104-012-9414-x.tif
# fig1_s12104-012-9415-9.tif
# fig1_s12104-012-9417-7.tif
# fig1_s12104-012-9419-5.tif
# fig1_s12104-012-9420-z.tif
# fig1_s12104-012-9422-x.tif
# fig1_s12104-012-9423-9.tif
# fig1_s12104-012-9425-7.tif
# fig1_s12104-012-9426-6.tif
# fig1_s12104-012-9428-4.tif
# fig1_s12104-012-9429-3.tif
# fig1_s12104-012-9433-7.tif
# fig1_s12104-012-9436-4.tif
# fig1_s12104-012-9437-3.tif
# fig1_s12104-012-9438-2.tif
# fig1_s12104-012-9439-1.tif
# fig1_s12104-012-9442-6.tif
# fig1_s12104-012-9443-5.tif
# fig1_s12104-012-9446-2.tif
# fig1_s12104-012-9448-0.tif
# fig1_s12104-012-9450-6.tif
# fig1_s12104-012-9452-4.tif
# fig1_s12104-012-9454-2.tif
# fig1_s12104-013-9457-7.tif
# fig1_s12104-013-9459-5.tif
# fig1_s12104-013-9462-x.tif
# fig1_s12104-013-9463-9.tif
# fig1_s12104-013-9465-7.tif
# fig1_s12104-013-9466-6.tif
# fig1_s12104-013-9467-5.tif
# fig1_s12104-013-9468-4.tif
# fig1_s12104-013-9469-3.tif
# fig1_s12104-013-9471-9.tif
# fig1_s12104-013-9472-8.tif
# fig1_s12104-013-9473-7.tif
# fig1_s12104-013-9474-6.tif
# fig1_s12104-013-9475-5.tif
# fig1_s12104-013-9476-4.tif
# fig1_s12104-013-9477-3.tif
# fig1_s12104-013-9478-2.tif
# fig1_s12104-013-9479-1.tif
# fig1_s12104-013-9480-8.tif
# fig1_s12104-013-9481-7.tif
# fig1_s12104-013-9483-5.tif
# fig1_s12104-013-9484-4.tif
# fig1_s12104-013-9486-2.tif
# fig1_s12104-013-9487-1.tif
# fig1_s12104-013-9489-z.tif
# fig1_s12104-013-9490-6.tif
# fig1_s12104-013-9492-4.tif
# fig1_s12104-013-9493-3.tif
# fig1_s12104-013-9494-2.tif
# fig1_s12104-013-9495-1.tif
# fig1_s12104-013-9496-0.tif
# fig1_s12104-013-9497-z.tif
# fig1_s12104-013-9498-y.tif
# fig1_s12104-013-9505-3.tif
# fig1_s12104-013-9506-2.tif
# fig1_s12104-013-9507-1.tif
# fig1_s12104-013-9509-z.tif
# fig1_s12104-013-9510-6.tif
# fig1_s12104-013-9511-5.tif
# fig1_s12104-013-9512-4.tif
# fig1_s12104-013-9514-2.tif
# fig1_s12104-013-9523-1.tif
# fig1_s12104-013-9525-z.tif
# fig1_s12104-013-9527-x.tif
# fig1_s12104-013-9528-9.tif
# fig1_s12104-013-9529-8.tif
# fig1_s12104-013-9530-2.tif
# fig1_s12104-013-9537-8.tif
# fig1_s12104-013-9538-7.tif
# fig1_s12104-013-9539-6.tif
# fig1_s12104-014-9540-8.tif
# fig1_s12104-014-9541-7.tif
# fig1_s12104-014-9542-6.tif
# fig1_s12104-014-9543-5.tif
# fig1_s12104-014-9544-4.tif
# fig1_s12104-014-9547-1.tif
# fig1_s12104-014-9548-0.tif
# fig1_s12104-014-9550-6.tif
# fig1_s12104-014-9551-5.tif
# fig1_s12104-014-9552-4.tif
# fig1_s12104-014-9554-2.tif
# fig1_s12104-014-9556-0.tif
# fig1_s12104-014-9558-y.tif
# fig1_s12104-014-9559-x.tif
# fig1_s12104-014-9560-4.tif
# fig1_s12104-014-9561-3.tif
# fig1_s12104-014-9562-2.tif
# fig1_s12104-014-9565-z.tif
# fig1_s12104-014-9566-y.tif
# fig1_s12104-014-9567-x.tif
# fig1_s12104-014-9568-9.tif
# fig1_s12104-014-9571-1.tif
# fig1_s12104-014-9572-0.tif
# fig1_s12104-014-9573-z.tif
# fig1_s12104-014-9576-9.tif
# fig1_s12104-014-9577-8.tif
# fig1_s12104-014-9578-7.tif
# fig1_s12104-014-9580-0.tif
# fig1_s12104-014-9581-z.tif
# fig1_s12104-014-9582-y.tif
# fig1_s12104-014-9584-9.tif
# fig1_s12104-014-9585-8.tif
# fig1_s12104-014-9588-5.tif
# fig1_s12104-014-9591-x.tif
# fig1_s12104-014-9593-8.tif
# fig1_s12104-014-9594-7.tif
# fig1_s12104-015-9595-1.tif
# fig1_s12104-015-9596-0.tif
# fig1_s12104-015-9597-z.tif
# fig1_s12104-015-9598-y.tif
# fig1_s12104-015-9599-x.tif
# fig1_s12104-015-9600-8.tif
# fig1_s12104-015-9601-7.tif
# fig1_s12104-015-9602-6.tif
# fig1_s12104-015-9604-4.tif
# fig1_s12104-015-9605-3.tif
# fig1_s12104-015-9607-1.tif
# fig1_s12104-015-9608-0.tif
# fig1_s12104-015-9610-6.tif
# fig1_s12104-015-9611-5.tif
# fig1_s12104-015-9612-4.tif
# fig1_s12104-015-9613-3.tif
# fig1_s12104-015-9614-2.tif
# fig1_s12104-015-9615-1.tif
# fig1_s12104-015-9616-0.tif
# fig1_s12104-015-9618-y.tif
# fig1_s12104-015-9619-x.tif
# fig1_s12104-015-9621-3.tif
# fig1_s12104-015-9623-1.tif
# fig1_s12104-015-9626-y.tif
# fig1_s12104-015-9627-x.tif
# fig1_s12104-015-9633-z.tif
# fig1_s12104-015-9635-x.tif
# fig1_s12104-015-9637-8.tif
# fig1_s12104-015-9638-7.tif
# fig1_s12104-015-9639-6.tif
# fig1_s12104-015-9640-0.tif
# fig1_s12104-015-9641-z.tif
# fig1_s12104-015-9642-y.tif
# fig1_s12104-015-9643-x.tif
# fig1_s12104-015-9644-9.tif
# fig1_s12104-015-9648-5.tif
# fig1_s12104-015-9649-4.tif
# fig1_s12104-015-9650-y.tif
# fig1_s12104-015-9651-x.tif
# fig1_s12104-015-9652-9.tif
# fig1_s12104-015-9653-8.tif
# fig1_s12104-015-9654-7.tif
# fig1_s12104-015-9656-5.tif
# fig1_s12104-015-9657-4.tif
# fig1_s12104-015-9660-9.tif
# fig1_s12104-015-9662-7.tif
# fig1_s12104-015-9663-6.tif
# fig1_s12104-016-9667-x.tif
# fig1_s12104-016-9668-9.tif
# fig1_s12104-016-9669-8.tif
# fig1_s12104-016-9670-2.tif
# fig1_s12104-016-9673-z.tif
# fig1_s12104-016-9674-y.tif
# fig1_s12104-016-9675-x.tif
# fig1_s12104-016-9676-9.tif
# fig1_s12104-016-9678-7.tif
# fig1_s12104-016-9686-7.tif
# fig1_s12104-016-9687-6.tif
# fig1_s12104-016-9689-4.tif
# fig1_s12104-016-9690-y.tif
# fig1_s12104-016-9691-x.tif
# fig1_s12104-016-9692-9.tif
# fig1_s12104-016-9693-8.tif
# fig1_s12104-016-9694-7.tif
# fig1_s12104-016-9695-6.tif
# fig1_s12104-016-9697-4.tif
# fig1_s12104-016-9698-3.tif
# fig1_s12104-016-9702-y.tif
# fig1_s12104-016-9703-x.tif
# fig1_s12104-016-9704-9.tif
# fig1_s12104-016-9705-8.tif
# fig1_s12104-016-9706-7.tif
# fig1_s12104-016-9707-6.tif
# fig1_s12104-016-9709-4.tif
# fig1_s12104-016-9710-y.tif
# fig1_s12104-016-9712-9.tif
# fig1_s12104-016-9713-8.tif
# fig1_s12104-016-9714-7.tif
# fig1_s12104-016-9716-5.tif
# fig1_s12104-016-9717-4.tif
# fig1_s12104-016-9719-2.tif
# fig1_s12104-016-9723-6.tif
# fig1_s12104-016-9724-5.tif
# fig1_s12104-016-9725-4.tif
# fig1_s12104-017-9726-y.tif
# fig1_s12104-017-9728-9.tif
# fig1_s12104-017-9730-2.tif
# fig1_s12104-017-9731-1.tif
# fig1_s12104-017-9732-0.tif
# fig1_s12104-017-9734-y.tif
# fig1_s12104-017-9735-x.tif
# fig1_s12104-017-9739-6.tif
# fig1_s12104-017-9740-0.tif
# fig1_s12104-017-9743-x.tif
# fig1_s12104-017-9746-7.tif
# fig1_s12104-017-9747-6.tif
# fig1_s12104-017-9748-5.tif
# fig1_s12104-017-9749-4.tif
# fig1_s12104-017-9752-9.tif
# fig1_s12104-017-9755-6.tif
# fig1_s12104-017-9758-3.tif
# fig1_s12104-017-9760-9.tif
# fig1_s12104-017-9761-8.tif
# fig1_s12104-017-9762-7.tif
# fig1_s12104-017-9763-6.tif
# fig1_s12104-017-9765-4.tif
# fig1_s12104-017-9766-3.tif
# fig1_s12104-017-9767-2.tif
# fig1_s12104-017-9769-0.tif
# fig1_s12104-017-9770-7.tif
# fig1_s12104-017-9772-5.tif
# fig1_s12104-017-9773-4.tif
# fig1_s12104-017-9775-2.tif
# fig1_s12104-017-9776-1.tif
# fig1_s12104-017-9777-0.tif
# fig1_s12104-017-9779-y.tif
# fig1_s12104-017-9780-5.tif
# fig1_s12104-017-9781-4.tif
# fig1_s12104-017-9782-3.tif
# fig1_s12104-017-9785-0.tif
# fig1_s12104-017-9786-z.tif
# fig1_s12104-017-9787-y.tif
# fig1_s12104-017-9791-2.tif
# fig1_s12104-017-9796-x.tif
# fig1_s12104-018-9798-3.tif
# fig1_s12104-018-9799-2.tif
# fig1_s12104-018-9800-0.tif
# fig1_s12104-018-9801-z.tif
# fig1_s12104-018-9804-9.tif
# fig1_s12104-018-9805-8.tif
# fig1_s12104-018-9806-7.tif
# fig1_s12104-018-9807-6.tif
# fig1_s12104-018-9809-4.tif
# fig1_s12104-018-9811-x.tif
# fig1_s12104-018-9812-9.tif
# fig1_s12104-018-9814-7.tif
# fig1_s12104-018-9815-6.tif
# fig1_s12104-018-9816-5.tif
# fig1_s12104-018-9817-4.tif
# fig1_s12104-018-9819-2.tif
# fig1_s12104-018-9820-9.tif
# fig1_s12104-018-9821-8.tif
# fig1_s12104-018-9822-7.tif
# fig1_s12104-018-9823-6.tif
# fig1_s12104-018-9824-5.tif
# fig1_s12104-018-9825-4.tif
# fig1_s12104-018-9828-1.tif
# fig1_s12104-018-9831-6.tif
# fig1_s12104-018-9832-5.tif
# fig1_s12104-018-9837-0.tif
# fig1_s12104-018-9839-y.tif
# fig1_s12104-018-9840-5.tif
# fig1_s12104-018-9844-1.tif
# fig1_s12104-018-9846-z.tif
# fig1_s12104-018-9847-y.tif
# fig1_s12104-018-9848-x.tif
# fig1_s12104-018-9849-9.tif
# fig1_s12104-018-9852-1.tif
# fig1_s12104-018-9853-0.tif
# fig1_s12104-018-9855-y.tif
# fig1_s12104-018-9856-x.tif
# fig1_s12104-018-9858-8.tif
# fig1_s12104-018-9859-7.tif
# fig1_s12104-018-9860-1.tif
# fig1_s12104-018-9862-z.tif
# fig1_s12104-018-9866-8.tif
# fig1_s12104-018-09869-4.tif
# fig1_s12104-018-09870-x.tif
# fig1_s12104-019-09871-4.tif
# fig1_s12104-019-09874-1.tif
# fig1_s12104-019-09881-2.tif
# fig1_s12104-019-09882-1.tif
# fig1_s12104-019-09884-z.tif
# fig1_s12104-019-09885-y.tif
# fig1_s12104-019-09886-x.tif
# fig1_s12104-019-09889-8.tif
# fig1_s12104-019-09890-1.tif
# fig1_s12104-019-09894-x.tif
# fig1_s12104-019-09895-w.tif
# fig1_s12104-019-09896-9.tif
# fig1_s12104-019-09898-7.tif
# fig1_s12104-019-09899-6.tif
# fig1_s12104-019-09900-2.tif
# fig1_s12104-019-09901-1.tif
# fig1_s12104-019-09902-0.tif
# fig1_s12104-019-09903-z.tif
# fig1_s12104-019-09904-y.tif
# fig1_s12104-019-09905-x.tif
# fig1_s12104-019-09907-9.tif
# fig1_s12104-019-09908-8.tif
# fig1_s12104-019-09909-7.tif
# fig1_s12104-019-09910-0.tif
# fig1_s12104-019-09912-y.tif
# fig1_s12104-019-09914-w.tif
# fig1_s12104-019-09915-9.tif
# fig1_s12104-019-09916-8.tif
# fig1_s12104-019-09917-7.tif
# fig1_s12104-019-09919-5.tif
# fig1_s12104-019-09921-x.tif
# fig1_s12104-019-09922-w.tif
# fig1_s12104-019-09923-9.tif
# fig1_s12104-020-09926-x.tif
# fig1_s12104-020-09927-w.tif
# fig1_s12104-020-09929-8.tif
# fig1_s12104-020-09930-1.tif
# fig1_s12104-020-09931-0.tif
# fig1_s12104-020-09933-y.tif
# fig1_s12104-020-09935-w.tif
# fig1_s12104-020-09943-w.tif
# fig1_s12104-020-09945-8.tif
# fig1_s12104-020-09946-7.tif
# fig1_s12104-020-09947-6.tif
# fig1_s12104-020-09948-5.tif
# fig1_s12104-020-09950-x.tif
# fig1_s12104-020-09954-7.tif
# fig1_s12104-020-09955-6.tif
# fig1_s12104-020-09956-5.tif
# fig1_s12104-020-09960-9.tif
# fig1_s12104-020-09961-8.tif
# fig1_s12104-020-09962-7.tif
# fig1_s12104-020-09963-6.tif
# fig1_s12104-020-09973-4.tif
# fig1_s12104-020-09976-1.tif
# fig1_s12104-020-09977-0.tif
# fig1_s12104-020-09978-z.tif
# fig1_s12104-020-09979-y.tif
# fig1_s12104-020-09980-5.tif
# fig1_s12104-020-09982-3.tif
# fig1_s12104-020-09984-1.tif
# fig1_s12104-020-09986-z.tif
# fig1_s12104-020-09987-y.tif
# fig1_s12104-020-09990-3.tif
# fig1_s12104-020-09992-1.tif
# fig1_s12104-020-09993-0.tif
# fig1_s12104-020-09994-z.tif
# fig1_s12104-020-09999-8.tif
# fig1_s12104-020-10002-7.tif
# fig1_s12104-020-10003-6.tif
# fig1_s12104-023-10159-x.tif
# fig1_s12104-024-10170-w.tif
# fig1_s12104-024-10193-3.tif
# fig2_s12104-015-9610-6.tif
# fig2_s12104-017-9742-y.tif
# fig2_s12104-018-9811-x.tif
# fig2_s12104-018-9837-0.tif

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (3251, 2622). Assuming channel dimension is last with 2622 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = 'None' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
import os

# 1.  Make sure the image has a channel axis
img = io.imread(files[0])          # (H, W)  or  (H, W, C)

if img.ndim == 2:                  # HSQC → single-channel
    img = img[..., None]           # (H, W, 1)

n_channels = img.shape[-1]         # now always ≥ 1


# 2.  Parse the dropdowns and validate indices
selected_channels = []
for c in [first_channel, second_channel, third_channel]:
    if c == 'None':
        continue
    idx = int(c)
    assert 0 <= idx < n_channels, (
        f'Invalid channel index {idx}; image has only {n_channels} channel(s).'
    )
    selected_channels.append(idx)

# Fallback: if the user picked nothing, just use the first channel
if not selected_channels:
    selected_channels = [0]


# 3.  Build the input volume for Cellpose
img_selected_channels = img[..., selected_channels]      # shape (H, W, len(selected))


# 4.  Run Cellpose
flow_threshold       = 0.4
cellprob_threshold   = 0.0
tile_norm_blocksize  = 0

masks, flows, styles = model.eval(
    img_selected_channels,
    batch_size          = 32,
    flow_threshold      = flow_threshold,
    cellprob_threshold  = cellprob_threshold,
    normalize           = {"tile_norm_blocksize": tile_norm_blocksize},
)


# 5.  Visualise and save
fig = plt.figure(figsize=(12, 5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()

os.makedirs("results", exist_ok=True)
plt.imsave("results/segmentation_mask.png", masks, cmap='viridis')
fig.savefig("results/segmentation_overlay.png", dpi=300)

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])

# %% [markdown]
# to save your masks for ImageJ, run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
    io.save_rois(masks0, f)
